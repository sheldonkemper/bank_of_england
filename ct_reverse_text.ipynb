# %% [markdown]
# <a href="https://colab.research.google.com/github/sheldonkemper/bank_of_england/blob/tidy_up_preprocessing_notebook/ct_reverse_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/bank_of_england/data/preprocessed_data/Archived/jpmorgan_qa_section_preprocessed.csv")

# %%
df.head()
# Out:
#          speaker marker                               job_title  \
# 0  Jeremy Barnum      A  Chief Financial Officer, JPMorganChase
# 1      Mike Mayo      Q     Analyst, Wells Fargo Securities LLC
# 2      Mike Mayo      Q     Analyst, Wells Fargo Securities LLC
# 3       Operator    NaN                                     NaN
# 4   Jim Mitchell      Q  Analyst, Seaport Global Securities LLC
#
#                                            utterance  \
# 0  Yeah. I think the conventional wisdom on QT, a...
# 1  So, you'll stay around maybe for a few more ye...
# 2                              All right. Thank you.
# 3  Thank you. Our next question comes from Jim Mi...
# 4  Hey. Good morning. Maybe just on regulation, w...
#
#                        filename financial_quarter   call_date  \
# 0  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 1  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 2  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 3  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 4  4q24-earnings-transcript.pdf              4Q24  2025-01-15
#
#                                       tokenised_data  \
# 0  ['yeah', 'think', 'conventional', 'wisdom', 'p...
# 1  ['stay', 'around', 'maybe', 'years', 'base', '...
# 2                          ['right', 'thank', 'you']
# 3  ['thank', 'you', 'next', 'question', 'comes', ...
# 4  ['hey', 'good', 'morning', 'maybe', 'regulatio...
#
#                                         cleaned_data
# 0  ['yeah think conventional wisdom qt im pretend...
# 1  ['so stay around maybe years base case right n...
# 2                                ['right thank you']
# 3  ['thank you next question comes jim mitchell s...
# 4  ['hey good morning maybe regulation new admini...
