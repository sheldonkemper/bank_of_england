# %% [markdown]
# <a href="https://colab.research.google.com/github/sheldonkemper/bank_of_england/blob/main/notebooks/modelling/BERT_test_RB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !pip install nltk
import nltk
# Stopwords dowload
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
import re
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('/content/sample_data/qa_section.csv', header=0)

# %%
df.head()
# Out:
#          speaker marker                               job_title  \
# 0  Jeremy Barnum      A  Chief Financial Officer, JPMorganChase
# 1      Mike Mayo      Q     Analyst, Wells Fargo Securities LLC
# 2      Mike Mayo      Q     Analyst, Wells Fargo Securities LLC
# 3       Operator    NaN                                     NaN
# 4   Jim Mitchell      Q  Analyst, Seaport Global Securities LLC
#
#                                            utterance  \
# 0  Yeah. I think the conventional wisdom on QT, a...
# 1  So, you'll stay around maybe for a few more ye...
# 2                              All right. Thank you.
# 3  Thank you. Our next question comes from Jim Mi...
# 4  Hey. Good morning. Maybe just on regulation, w...
#
#                        filename financial_quarter   call_date
# 0  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 1  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 2  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# ...

# %%
# Remove rows where speaker == "operator"
df_filtered = df[df['speaker'] != 'Operator']

# Display result
df_filtered.head()
# Out:
#          speaker marker                               job_title  \
# 0  Jeremy Barnum      A  Chief Financial Officer, JPMorganChase
# 1      Mike Mayo      Q     Analyst, Wells Fargo Securities LLC
# 2      Mike Mayo      Q     Analyst, Wells Fargo Securities LLC
# 4   Jim Mitchell      Q  Analyst, Seaport Global Securities LLC
# 5  Jeremy Barnum      A  Chief Financial Officer, JPMorganChase
#
#                                            utterance  \
# 0  Yeah. I think the conventional wisdom on QT, a...
# 1  So, you'll stay around maybe for a few more ye...
# 2                              All right. Thank you.
# 4  Hey. Good morning. Maybe just on regulation, w...
# 5  Hey, Jim. I mean, it's obviously something we'...
#
#                        filename financial_quarter   call_date
# 0  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 1  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 2  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# ...

# %%
# Filtering only on Answers
df_2 = df_filtered[df_filtered['marker'] == 'A']

# Display result
df_2.head()
# Out:
#          speaker marker                                          job_title  \
# 0  Jeremy Barnum      A             Chief Financial Officer, JPMorganChase
# 5  Jeremy Barnum      A             Chief Financial Officer, JPMorganChase
# 6  Jeremy Barnum      A             Chief Financial Officer, JPMorganChase
# 7    Jamie Dimon      A  Chairman & Chief Executive Officer, JPMorganChase
# 9  Jeremy Barnum      A             Chief Financial Officer, JPMorganChase
#
#                                            utterance  \
# 0  Yeah. I think the conventional wisdom on QT, a...
# 5  Hey, Jim. I mean, it's obviously something we'...
# 6  everything, more capital, more liquidity, that...
# 7  Can I just add, no that's great. Jeremy gave i...
# 9  Yeah, it's a good question. And I think given ...
#
#                        filename financial_quarter   call_date
# 0  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 5  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# ...

# %% [markdown]
# **Preprocess the data**

# %%
# Stopwords dowload
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Define the preprocessing function
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove numbers
    text = re.sub(r'[^A-Za-z]+', ' ', text)

    # Remove stopwords
    words = text.split()
    words = [word for word in words if word not in stop_words]

    # Join the words back into a single string
    return ' '.join(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Apply the function, handling potential float values
df_2['utterance'] = df_2['utterance'].astype(str).apply(preprocess_text)

# Display the first few rows to confirm changes
df_2.head(5)
# Out:
#          speaker marker                                          job_title  \
# 0  Jeremy Barnum      A             Chief Financial Officer, JPMorganChase
# 5  Jeremy Barnum      A             Chief Financial Officer, JPMorganChase
# 6  Jeremy Barnum      A             Chief Financial Officer, JPMorganChase
# 7    Jamie Dimon      A  Chairman & Chief Executive Officer, JPMorganChase
# 9  Jeremy Barnum      A             Chief Financial Officer, JPMorganChase
#
#                                            utterance  \
# 0  yeah think conventional wisdom qt pretending a...
# 5  hey jim mean obviously something thinking lot ...
# 6  everything capital liquidity uses data balance...
# 7  add great jeremy gave let add three quick thin...
# 9  yeah good question think given significant imp...
#
#                        filename financial_quarter   call_date
# 0  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# 5  4q24-earnings-transcript.pdf              4Q24  2025-01-15
# ...

# %%
# Convert the 'Comment' column to a list
comments = df_2['utterance']

# %%
comments = []
for review in comments:
  #print(review)
  if review is not None and review != "nan":
    review = review.lower()
    review = re.sub('[^A-Za-z]+', ' ', review)

    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(review)

    for w in word_tokens:
      if w in stop_words:
        review = review.replace(" " + w + " ", " ")
    comments.append(review)

# %%
# Convert the 'Comment' column to a list
comments = df_2['utterance'].tolist()

# %%
print(comments[1:10])
# Out:
# ['hey jim mean obviously something thinking lot could go pretty deep rabbit holes speculating different parts framework could evolve really think productive right let make attempt answer question backing second read jamie quotes consistent saying company long time want coherent rational holistically assessed regulatory framework allows banks job supporting economy reflexively anti bank default answer every question', 'everything capital liquidity uses data balances obvious goal share safe sound banking system actually recognizing banks play critical role supporting growth hope get also aspects supervisory framework get little bit less bureaucratic little less adversarial little bit substantive margin management focus time things matter whether capital goes stays flat really complicated basel iii endgame also g sib also number factors keep hammering away importance holistically properly right analysis takes time', 'add great jeremy gave let add three quick things liquidity also equall
# ...

# %%
# Define a function to reset the session.
def reset_session():
    tf.keras.backend.clear_session()
    np.random.seed(42)
    random.seed(42)
    tf.random.set_seed(42)

# %%
# !pip install tensorflow
# !pip install numpy
# !pip install bertopic


import tensorflow as tf
import numpy as np
import random
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import tensorflow as tf
from umap import UMAP

# %%
# Define a function to reset the session.
def reset_session():
    tf.keras.backend.clear_session()
    np.random.seed(42)
    random.seed(42)
    tf.random.set_seed(42)
#reset_session()

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
###vectorizer_model = CountVectorizer(max_df=0.8, min_df=2)
umap_model = UMAP(n_neighbors=20, min_dist=0.1)

model2 = BERTopic(embedding_model=embedding_model, umap_model=umap_model, verbose=True)
model2.fit(comments)
topic, probabilities = model2.transform(comments)
# Out:
# 2025-02-06 21:30:29,479 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# 2025-02-06 21:30:43,398 - BERTopic - Embedding - Completed ✓
# 2025-02-06 21:30:43,402 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-02-06 21:30:43,962 - BERTopic - Dimensionality - Completed ✓
# 2025-02-06 21:30:43,965 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-02-06 21:30:43,980 - BERTopic - Cluster - Completed ✓
# 2025-02-06 21:30:43,984 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-02-06 21:30:44,014 - BERTopic - Representation - Completed ✓
# Batches:   0%|          | 0/11 [00:00<?, ?it/s]
# 2025-02-06 21:30:56,353 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-02-06 21:30:56,359 - BERTopic - Dimensionality - Completed ✓
# ...

# %%
model2.get_topic_freq().head(10)
# Out:
#    Topic  Count
# 0      0    237
# 1      1     94
# 2      2     11

# %%
model2.get_topic(0)
# Out:
# [('think', 0.0538907296878889),
#  ('bit', 0.03767965954122752),
#  ('little', 0.0367162483910615),
#  ('going', 0.03398098977129065),
#  ('like', 0.03094237560762119),
#  ('yeah', 0.029647511031219053),
#  ('capital', 0.02931734595592684),
#  ('would', 0.029109421516523102),
#  ('see', 0.026419465811247853),
#  ('things', 0.025111909233928694)]

# %%
import plotly.io as pio

fig = model2.visualize_barchart(top_n_topics=10, n_words=5)
fig.update_layout(
    autosize=False,
    width=1000,
    height=800,
    margin=dict(l=50, r=50, t=100, b=50),
    font=dict(size=12),
    title=dict(
        text="Top 10 Topics and Their Key Words",
        font=dict(size=16),
        x=0.5,
        y=0.98,
        xanchor="center",
        yanchor="top"
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
