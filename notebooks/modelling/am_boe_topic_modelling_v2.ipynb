# %% [markdown]
# <a href="https://colab.research.google.com/github/sheldonkemper/bank_of_england/blob/main/notebooks/modelling/am_boe_topic_modelling_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ############################################
# # Topic Modeling Using GPT-4-Turbo on Financial Text
# ############################################
# #
# # This script processes financial text data from CSV files using GPT-4-Turbo to identify topics discussed in the text.
# # It follows these steps:
# #
# # Step 1: Load the input CSV file into a pandas DataFrame.
# # Step 2: Define a function to interact with OpenAI GPT-4-Turbo to extract topics and their descriptions.
# # Step 3: Apply this function to the 'Question_cleand' column to create topic-related columns.
# # Step 4: Apply the same function to the 'Response_cleand' column.
# # Step 5: Save the final DataFrame to a CSV file.
# #
# # Required Libraries:
# # - openai: For interacting with GPT-4-Turbo.
# # - pandas: For handling data operations.
# # - os: For managing environment variables.
# ############################################

# %%
# Install required libraries (if not already installed)
# !pip install -q openai==0.28
# !pip install -q pandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.1 MB/s eta 0:00:00

# %%
# Import necessary libraries
import openai
import pandas as pd
import os
import re

# Ensure OpenAI API key is set
openai_api_key = os.getenv("Openai_key")

# %%
############################################
# Step 1: Load CSV Files into DataFrame
############################################

# Load the CSV file (assuming the user uploads it)
input_df = pd.read_csv("/content/ubs_qa_df_preprocessed_ver2.csv")
print("CSV file loaded successfully.")
# Out:
# CSV file loaded successfully.

# %%
input_df
# Out:
#                           filename Quarter  \
# 0   1q23-earnings-call-remarks.pdf    1Q23
# 1   1q23-earnings-call-remarks.pdf    1Q23
# 2   1q23-earnings-call-remarks.pdf    1Q23
# 3   1q23-earnings-call-remarks.pdf    1Q23
# 4   1q23-earnings-call-remarks.pdf    1Q23
# ..                             ...     ...
# 91  4q24-earnings-call-remarks.pdf    4Q24
# 92  4q24-earnings-call-remarks.pdf    4Q24
# 93  4q24-earnings-call-remarks.pdf    4Q24
# 94  4q24-earnings-call-remarks.pdf    4Q24
# 95  4q24-earnings-call-remarks.pdf    4Q24
#
#                                              Question  \
# 0   Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1   Yeah. Thanks. Just two questions. The first on...
# 2   Yeah. Thank you. Good morning. Welcome back, S...
# 3   Yes. Good morning. The first question I wanted...
# 4   Good morning. Two questions. Firstly, just on ...
# ..                                                ...
# 91  Good morning. One follow-up on GWM Americas an...
# 92                 Very helpful. Thank you very much.
# 93  Hi. Thank you and thank you for the clarificat...
# 94  Good morning. It's Antonio from Bank of Americ...
# 95  Yes, good morning, everybody. I just got two f...
#
#                                      Question_cleaned         Analyst_Bank  \
# 0   ['okay thank you capital requirements know sit...              Goldman
# 1   ['so sarah take first question take secondso g...             JPMorgan
# 2   ['thank you ryan good back interact well look ...      Bank of America
# 3   ['so first question terms trends april really ...            Jefferies
# 4   ['so first quarter first question seen signifi...                 Citi
# ..                                                ...                  ...
# 91  ['first first question respect fa comp changes...                 Citi
# 92                                               ['']  Autonomous Research
# 93  ['yeah terms expectations really articulated s...           Mediobanca
# 94  ['terms mitigants bit headwinds know definitel...      Bank of America
# 95  ['hi piers – take second question first terms ...                 HSBC
#
#                                              Response  \
# 0   Okay. Thank you. On capital requirements, you ...
# 1   So, Sarah, take the first question. I'll take ...
# 2   Thank you, Ryan. It is good to be back to inte...
# 3   So, on the first question in terms of the tren...
# 4   So, on the first quarter or the first question...
# ..                                                ...
# 91  So first, on your first question in respect to...
# 92                                                NaN
# 93  Yeah. So in terms of the expectations, we have...
# 94  So in terms of the mitigants a bit to the head...
# 95  Hi Piers, so on – I'll just take your second q...
#
#                                      Response_cleaned  \
# 0   ['chis hallam goldman sachs yes good morning e...
# 1   ['yeah thanks two questions first one related ...
# 2   ['yeah thank you good morning welcome back ser...
# 3   ['yes good morning first question wanted ask r...
# 4   ['good morning two questions firstly slide 10 ...
# ..                                                ...
# 91  ['good morning one follow-up gwm americas perh...
# 92                             ['helpful thank much']
# 93  ['hi thank thank clarifications capital got co...
# 94  ['good morning antonio bank america two questi...
# 95  ['yes good morning everybody got two follow-up...
#
#                                    Executive
# 0                      ['Sergio P. Ermotti']
# 1   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 2                      ['Sergio P. Ermotti']
# 3   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4                        ['Sarah Youngwood']
# ..                                       ...
# 91                          ['Todd Tuckner']
# 92                                        []
# 93                          ['Todd Tuckner']
# 94                          ['Todd Tuckner']
# 95     ['Todd Tuckner', 'Sergio P. Ermotti']
#
# [96 rows x 8 columns]

# %%
############################################
# Step 2: Define Function to Extract Topics using GPT-4-Turbo
############################################
print("Defining GPT-4-Turbo function for topic extraction...")

def extract_topics(text):
    """
    This function takes a financial text input and analyzes the topics discussed in the text.
    It returns a list of topics and corresponding sentences that contributed to each topic.
    """
    if pd.isna(text) or text.strip() == "":
        return "No Topic", "No Relevant Sentences"

    prompt = f"""
    Analyze the following financial text and extract distinct topics discussed.
    Provide:
    1. The topic names.
    2. Example sentences that helped you identify the topic.

    Text:
    {text}
    """

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4-turbo",
            messages=[{"role": "user", "content": prompt}]
        )

        result = response["choices"][0]["message"]["content"]

        # Splitting response into topic and description
        if "\n" in result:
            parts = result.split("\n", 1)
            topic = parts[0].strip()
            topic_description = parts[1].strip()
        else:
            topic = result.strip()
            topic_description = "Description not available"

        return topic, topic_description
    except Exception as e:
        return "Error", str(e)
# Out:
# Defining GPT-4-Turbo function for topic extraction...

# %%
############################################
# Step 3: Apply Function to 'Question_cleand' Column
############################################

input_df[['Question_topic', 'Question_topic_description']] = input_df['Question_cleaned'].apply(
    lambda x: pd.Series(extract_topics(x))
)

question_df = input_df.copy()
print("Topic extraction for questions completed.")
# Out:
# Topic extraction for questions completed.

# %%
question_df
# Out:
#                           filename Quarter  \
# 0   1q23-earnings-call-remarks.pdf    1Q23
# 1   1q23-earnings-call-remarks.pdf    1Q23
# 2   1q23-earnings-call-remarks.pdf    1Q23
# 3   1q23-earnings-call-remarks.pdf    1Q23
# 4   1q23-earnings-call-remarks.pdf    1Q23
# ..                             ...     ...
# 91  4q24-earnings-call-remarks.pdf    4Q24
# 92  4q24-earnings-call-remarks.pdf    4Q24
# 93  4q24-earnings-call-remarks.pdf    4Q24
# 94  4q24-earnings-call-remarks.pdf    4Q24
# 95  4q24-earnings-call-remarks.pdf    4Q24
#
#                                              Question  \
# 0   Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1   Yeah. Thanks. Just two questions. The first on...
# 2   Yeah. Thank you. Good morning. Welcome back, S...
# 3   Yes. Good morning. The first question I wanted...
# 4   Good morning. Two questions. Firstly, just on ...
# ..                                                ...
# 91  Good morning. One follow-up on GWM Americas an...
# 92                 Very helpful. Thank you very much.
# 93  Hi. Thank you and thank you for the clarificat...
# 94  Good morning. It's Antonio from Bank of Americ...
# 95  Yes, good morning, everybody. I just got two f...
#
#                                      Question_cleaned         Analyst_Bank  \
# 0   ['okay thank you capital requirements know sit...              Goldman
# 1   ['so sarah take first question take secondso g...             JPMorgan
# 2   ['thank you ryan good back interact well look ...      Bank of America
# 3   ['so first question terms trends april really ...            Jefferies
# 4   ['so first quarter first question seen signifi...                 Citi
# ..                                                ...                  ...
# 91  ['first first question respect fa comp changes...                 Citi
# 92                                               ['']  Autonomous Research
# 93  ['yeah terms expectations really articulated s...           Mediobanca
# 94  ['terms mitigants bit headwinds know definitel...      Bank of America
# 95  ['hi piers – take second question first terms ...                 HSBC
#
#                                              Response  \
# 0   Okay. Thank you. On capital requirements, you ...
# 1   So, Sarah, take the first question. I'll take ...
# 2   Thank you, Ryan. It is good to be back to inte...
# 3   So, on the first question in terms of the tren...
# 4   So, on the first quarter or the first question...
# ..                                                ...
# 91  So first, on your first question in respect to...
# 92                                                NaN
# 93  Yeah. So in terms of the expectations, we have...
# 94  So in terms of the mitigants a bit to the head...
# 95  Hi Piers, so on – I'll just take your second q...
#
#                                      Response_cleaned  \
# 0   ['chis hallam goldman sachs yes good morning e...
# 1   ['yeah thanks two questions first one related ...
# 2   ['yeah thank you good morning welcome back ser...
# 3   ['yes good morning first question wanted ask r...
# 4   ['good morning two questions firstly slide 10 ...
# ..                                                ...
# 91  ['good morning one follow-up gwm americas perh...
# 92                             ['helpful thank much']
# 93  ['hi thank thank clarifications capital got co...
# 94  ['good morning antonio bank america two questi...
# 95  ['yes good morning everybody got two follow-up...
#
#                                    Executive  \
# 0                      ['Sergio P. Ermotti']
# 1   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 2                      ['Sergio P. Ermotti']
# 3   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4                        ['Sarah Youngwood']
# ..                                       ...
# 91                          ['Todd Tuckner']
# 92                                        []
# 93                          ['Todd Tuckner']
# 94                          ['Todd Tuckner']
# 95     ['Todd Tuckner', 'Sergio P. Ermotti']
#
#                                        Question_topic  \
# 0            ### Topics Analysis from Financial Text:
# 1   The provided financial text discusses multiple...
# 2   Based on the text provided, several distinct t...
# 3   The financial text provided discusses several ...
# 4   From the provided financial text, several dist...
# ..                                                ...
# 91  From the provided financial text, the followin...
# 92  It appears that the provided text is empty, as...
# 93  Based on the provided financial text, I have i...
# 94  From the provided text which seems to be part ...
# 95  Based on the provided text, the conversation a...
#
#                            Question_topic_description
# 0   1. **Capital Requirements and Scope of Perimet...
# 1   1. **Economic Impact Analysis**\n   - Example ...
# 2   1. **Topic Name: Asset Management and Restruct...
# 3   1. **Regional Strengths and Complementarity in...
# 4   1. **Mix Shifts in Financial Systems**\n   - *...
# ..                                                ...
# 91  1. **Compensation and Strategy Alignment**\n  ...
# 92                          Description not available
# 93  1. **Financial Expectations and Goals**:\n   -...
# 94  1. **Revenue Growth and Hedging Strategies**\n...
# 95  1. **Basel III Impact and Internal Management*...
#
# [96 rows x 10 columns]

# %%
############################################
# Step 4: Apply Function to 'Response_cleand' Column
############################################
print("Applying GPT-4-Turbo function on 'Response_cleand' column...")

question_df[['Answer_topic', 'Answer_topic_description']] = question_df['Response_cleaned'].apply(
    lambda x: pd.Series(extract_topics(x))
)

final_df = question_df.copy()
print("Topic extraction for responses completed.")
# Out:
# Applying GPT-4-Turbo function on 'Response_cleand' column...
# Topic extraction for responses completed.

# %%
final_df
# Out:
#                           filename Quarter  \
# 0   1q23-earnings-call-remarks.pdf    1Q23
# 1   1q23-earnings-call-remarks.pdf    1Q23
# 2   1q23-earnings-call-remarks.pdf    1Q23
# 3   1q23-earnings-call-remarks.pdf    1Q23
# 4   1q23-earnings-call-remarks.pdf    1Q23
# ..                             ...     ...
# 91  4q24-earnings-call-remarks.pdf    4Q24
# 92  4q24-earnings-call-remarks.pdf    4Q24
# 93  4q24-earnings-call-remarks.pdf    4Q24
# 94  4q24-earnings-call-remarks.pdf    4Q24
# 95  4q24-earnings-call-remarks.pdf    4Q24
#
#                                              Question  \
# 0   Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1   Yeah. Thanks. Just two questions. The first on...
# 2   Yeah. Thank you. Good morning. Welcome back, S...
# 3   Yes. Good morning. The first question I wanted...
# 4   Good morning. Two questions. Firstly, just on ...
# ..                                                ...
# 91  Good morning. One follow-up on GWM Americas an...
# 92                 Very helpful. Thank you very much.
# 93  Hi. Thank you and thank you for the clarificat...
# 94  Good morning. It's Antonio from Bank of Americ...
# 95  Yes, good morning, everybody. I just got two f...
#
#                                      Question_cleaned         Analyst_Bank  \
# 0   ['okay thank you capital requirements know sit...              Goldman
# 1   ['so sarah take first question take secondso g...             JPMorgan
# 2   ['thank you ryan good back interact well look ...      Bank of America
# 3   ['so first question terms trends april really ...            Jefferies
# 4   ['so first quarter first question seen signifi...                 Citi
# ..                                                ...                  ...
# 91  ['first first question respect fa comp changes...                 Citi
# 92                                               ['']  Autonomous Research
# 93  ['yeah terms expectations really articulated s...           Mediobanca
# 94  ['terms mitigants bit headwinds know definitel...      Bank of America
# 95  ['hi piers – take second question first terms ...                 HSBC
#
#                                              Response  \
# 0   Okay. Thank you. On capital requirements, you ...
# 1   So, Sarah, take the first question. I'll take ...
# 2   Thank you, Ryan. It is good to be back to inte...
# 3   So, on the first question in terms of the tren...
# 4   So, on the first quarter or the first question...
# ..                                                ...
# 91  So first, on your first question in respect to...
# 92                                                NaN
# 93  Yeah. So in terms of the expectations, we have...
# 94  So in terms of the mitigants a bit to the head...
# 95  Hi Piers, so on – I'll just take your second q...
#
#                                      Response_cleaned  \
# 0   ['chis hallam goldman sachs yes good morning e...
# 1   ['yeah thanks two questions first one related ...
# 2   ['yeah thank you good morning welcome back ser...
# 3   ['yes good morning first question wanted ask r...
# 4   ['good morning two questions firstly slide 10 ...
# ..                                                ...
# 91  ['good morning one follow-up gwm americas perh...
# 92                             ['helpful thank much']
# 93  ['hi thank thank clarifications capital got co...
# 94  ['good morning antonio bank america two questi...
# 95  ['yes good morning everybody got two follow-up...
#
#                                    Executive  \
# 0                      ['Sergio P. Ermotti']
# 1   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 2                      ['Sergio P. Ermotti']
# 3   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4                        ['Sarah Youngwood']
# ..                                       ...
# 91                          ['Todd Tuckner']
# 92                                        []
# 93                          ['Todd Tuckner']
# 94                          ['Todd Tuckner']
# 95     ['Todd Tuckner', 'Sergio P. Ermotti']
#
#                                        Question_topic  \
# 0            ### Topics Analysis from Financial Text:
# 1   The provided financial text discusses multiple...
# 2   Based on the text provided, several distinct t...
# 3   The financial text provided discusses several ...
# 4   From the provided financial text, several dist...
# ..                                                ...
# 91  From the provided financial text, the followin...
# 92  It appears that the provided text is empty, as...
# 93  Based on the provided financial text, I have i...
# 94  From the provided text which seems to be part ...
# 95  Based on the provided text, the conversation a...
#
#                            Question_topic_description  \
# 0   1. **Capital Requirements and Scope of Perimet...
# 1   1. **Economic Impact Analysis**\n   - Example ...
# 2   1. **Topic Name: Asset Management and Restruct...
# 3   1. **Regional Strengths and Complementarity in...
# 4   1. **Mix Shifts in Financial Systems**\n   - *...
# ..                                                ...
# 91  1. **Compensation and Strategy Alignment**\n  ...
# 92                          Description not available
# 93  1. **Financial Expectations and Goals**:\n   -...
# 94  1. **Revenue Growth and Hedging Strategies**\n...
# 95  1. **Basel III Impact and Internal Management*...
#
#                                          Answer_topic  \
# 0                ### 1. Topics discussed in the text:
# 1   Based on the analysis of the provided financia...
# 2   Based on the text provided, here are the topic...
# 3   Based on the given financial text, several dis...
# 4   The text involves a financial discussion focus...
# ..                                                ...
# 91  From the provided text, the following distinct...
# 92  Based on the provided text "helpful thank much...
# 93  Upon analyzing the provided text, distinct top...
# 94  The analyzed financial text discusses two main...
# 95  Based on the provided financial text, here are...
#
#                              Answer_topic_description
# 0   **Topic 1: Capital Requirements and Regulatory...
# 1   1. **Book Value Per Share Guidance:**\n   - Ex...
# 2   1. **Merger and Acquisition Strategy**\n   - *...
# 3   1. **Net New Money Trends**\n   - _"first ques...
# 4   1. **Net Interest Income (NII) Forecast and Ra...
# ..                                                ...
# 91  1. **Strategic Changes and Incentives in GWM A...
# 92  1. **Customer Service or Support**\n   - Examp...
# 93  1. **Future Profitability Goals:**\n   - **Top...
# 94  1. **Capital Management in Banking**\n   - Exa...
# 95  1. **Client Risk Appetite and Banking Activity...
#
# [96 rows x 12 columns]

# %%
############################################
# Step 5: Save Final DataFrame to CSV
############################################
print("Saving final DataFrame to CSV...")

final_df.to_csv("tqc_topic_model_jpmorgan.csv", index=False)
print("CSV file saved successfully.")
# Out:
# Saving final DataFrame to CSV...
# CSV file saved successfully.

# %%
# Function to split topics and expand rows
def split_topics(row):
    topics = re.split(r'\n?\d+\.\s\*\*(.*?)\*\*:', row['Answer_topic_description'])
    topics = [t.strip() for t in topics if t.strip()]  # Remove empty entries
    return pd.DataFrame([{**row, 'Answer_topic_description': t} for t in topics])

# Apply the function to each row and reset the index
expanded_df = pd.concat([split_topics(row) for _, row in final_df.iterrows()], ignore_index=True)

# Display the processed DataFrame
expanded_df
# Out:
#     Quarter                                           Question  \
# 0      4Q24  Hi. Good morning. Jeremy, I wanted to ask abou...
# 1      4Q24  Hi. Good morning. Jeremy, I wanted to ask abou...
# 2      4Q24  Hi. Good morning. Jeremy, I wanted to ask abou...
# 3      4Q24  Hi. Good morning. Jeremy, I wanted to ask abou...
# 4      4Q24  Hi. Good morning. Jeremy, I wanted to ask abou...
# ..      ...                                                ...
# 206    1Q23  Thank you. So you talked about in your letter ...
# 207    1Q23  Thank you. So you talked about in your letter ...
# 208    1Q23  Thank you. So you talked about in your letter ...
# 209    1Q23  Good morning. You guys talked about one of the...
# 210    1Q23             Excellent. Folks, thank you very much.
#
#                                       Question_cleaned        Analyst  \
# 0    ['hi good morning jeremy wanted ask capital kn...  John McDonald
# 1    ['hi good morning jeremy wanted ask capital kn...  John McDonald
# 2    ['hi good morning jeremy wanted ask capital kn...  John McDonald
# 3    ['hi good morning jeremy wanted ask capital kn...  John McDonald
# 4    ['hi good morning jeremy wanted ask capital kn...  John McDonald
# ..                                                 ...            ...
# 206  ['thank you talked letter regulators avoiding ...   Glenn Schorr
# 207  ['thank you talked letter regulators avoiding ...   Glenn Schorr
# 208  ['thank you talked letter regulators avoiding ...   Glenn Schorr
# 209  ['good morning guys talked one drivers higher ...  Matt O'Connor
# 210                     ['excellent folks thank much']    Jamie Dimon
#
#                                           Analyst Role  \
# 0                     Analyst, Truist Securities, Inc.
# 1                     Analyst, Truist Securities, Inc.
# 2                     Analyst, Truist Securities, Inc.
# 3                     Analyst, Truist Securities, Inc.
# 4                     Analyst, Truist Securities, Inc.
# ..                                                 ...
# 206                              Analyst, Evercore ISI
# 207                              Analyst, Evercore ISI
# 208                              Analyst, Evercore ISI
# 209            Analyst, Deutsche Bank Securities, Inc.
# 210  Chairman & Chief Executive Officer, JPMorgan C...
#
#                                               Response  \
# 0    Yeah. Good question, John, and welcome back, b...
# 1    Yeah. Good question, John, and welcome back, b...
# 2    Yeah. Good question, John, and welcome back, b...
# 3    Yeah. Good question, John, and welcome back, b...
# 4    Yeah. Good question, John, and welcome back, b...
# ..                                                 ...
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
# 210                                                NaN
#
#                                       Response_cleaned      Executive  \
# 0    ['yeah good question john welcome back way so ...  Jeremy Barnum
# 1    ['yeah good question john welcome back way so ...  Jeremy Barnum
# 2    ['yeah good question john welcome back way so ...  Jeremy Barnum
# 3    ['yeah good question john welcome back way so ...  Jeremy Barnum
# 4    ['yeah good question john welcome back way so ...  Jeremy Barnum
# ..                                                 ...            ...
# 206                                            ['nan']  Jeremy Barnum
# 207                                            ['nan']  Jeremy Barnum
# 208                                            ['nan']  Jeremy Barnum
# 209                                            ['nan']  Jeremy Barnum
# 210                                            ['nan']        Unknown
#
#     Executive Role Type                                     Question_topic  \
# 0                   CFO  Based on the provided text, here are the disti...
# 1                   CFO  Based on the provided text, here are the disti...
# 2                   CFO  Based on the provided text, here are the disti...
# 3                   CFO  Based on the provided text, here are the disti...
# 4                   CFO  Based on the provided text, here are the disti...
# ..                  ...                                                ...
# 206           CFO & Co.  Based on the analysis of the provided text, th...
# 207           CFO & Co.  Based on the analysis of the provided text, th...
# 208           CFO & Co.  Based on the analysis of the provided text, th...
# 209           CFO & Co.  Based on the provided financial text, there ar...
# 210             Unknown  The provided text, "excellent folks thank much...
#
#                             Question_topic_description  \
# 0    1. **Capital Management:**\n   - Example sente...
# 1    1. **Capital Management:**\n   - Example sente...
# 2    1. **Capital Management:**\n   - Example sente...
# 3    1. **Capital Management:**\n   - Example sente...
# 4    1. **Capital Management:**\n   - Example sente...
# ..                                                 ...
# 206  1. **Customer and Corporate Response to Financ...
# 207  1. **Customer and Corporate Response to Financ...
# 208  1. **Customer and Corporate Response to Financ...
# 209  1. **Net Interest Income and Credit Card Balan...
# 210  However, I can define a general topic:\n1. **G...
#
#                                           Answer_topic  \
# 0    Based on the provided financial text, the foll...
# 1    Based on the provided financial text, the foll...
# 2    Based on the provided financial text, the foll...
# 3    Based on the provided financial text, the foll...
# 4    Based on the provided financial text, the foll...
# ..                                                 ...
# 206  Based on the provided text which contains only...
# 207  Based on the provided text which contains only...
# 208  Based on the provided text which contains only...
# 209  The provided text consists solely of the term ...
# 210  The provided text contains only the entity 'na...
#
#                               Answer_topic_description
# 0    Strategic Financial Decisions & Capital Alloca...
# 1    - This topic is identified through the discuss...
# 2                  Investment Strategy and Focus Areas
# 3    - The focus is on high-certainty investment ch...
# 4             Operating Efficiency and Cost Management
# ..                                                 ...
# 206                        Unavailable or Missing Data
# 207                                   Example Sentence
# 208  In the entire input text, the only element ava...
# 209                          Description not available
# 210  Topic names and example sentences identificati...
#
# [211 rows x 13 columns]

# %%
# Function to extract topics and reformat the row
def extract_topics(row):
    # Splitting based on numbered pattern (1, 2, 3, etc.) while keeping the content
    sections = re.split(r'\n?\d+\.\s', row['Answer_topic_description'])
    sections = [s.strip() for s in sections if s.strip()]  # Remove empty entries

    # Create a new dictionary for the reformatted row
    new_row = row.to_dict()

    # Assign each section to a new numbered column
    for i, section in enumerate(sections):
        new_row[f"Topic_{i+1}"] = section  # Naming columns as Topic_1, Topic_2, etc.

    return new_row

# Apply the function and expand the DataFrame
expanded_df = pd.DataFrame([extract_topics(row) for _, row in final_df.iterrows()])

# Display the processed DataFrame
expanded_df
# Out:
#    Quarter                                           Question  \
# 0     4Q24  Hi. Good morning. Jeremy, I wanted to ask abou...
# 1     4Q24  Hi. Simple and then more difficult, I guess. J...
# 2     4Q24  Hey. Good morning. Maybe just on regulation, w...
# 3     4Q24  Yes. Hi, good morning. Wanted to follow up on ...
# 4     4Q24           Does that conclude your question, Erika?
# ..     ...                                                ...
# 86    1Q23  Hey Jeremy, you mentioned a degree of reinterm...
# 87    1Q23  Hi. Good morning.\nI do want to unpack the que...
# 88    1Q23  Thank you. So you talked about in your letter ...
# 89    1Q23  Good morning. You guys talked about one of the...
# 90    1Q23             Excellent. Folks, thank you very much.
#
#                                      Question_cleaned           Analyst  \
# 0   ['hi good morning jeremy wanted ask capital kn...     John McDonald
# 1   ['hi simple difficult guess jamie whos success...         Mike Mayo
# 2   ['hey good morning maybe regulation new admini...      Jim Mitchell
# 3   ['yes hi good morning wanted follow questions ...    Erika Najarian
# 4                         ['conclude question erika']             Erika
# ..                                                ...               ...
# 86  ['hey jeremy mentioned degree reintermediation...         Mike Mayo
# 87  ['hi good morning want unpack question possibi...  Betsy L. Graseck
# 88  ['thank you talked letter regulators avoiding ...      Glenn Schorr
# 89  ['good morning guys talked one drivers higher ...     Matt O'Connor
# 90                     ['excellent folks thank much']       Jamie Dimon
#
#                                          Analyst Role  \
# 0                    Analyst, Truist Securities, Inc.
# 1                 Analyst, Wells Fargo Securities LLC
# 2              Analyst, Seaport Global Securities LLC
# 3                         Analyst, UBS Securities LLC
# 4                                             Unknown
# ..                                                ...
# 86                Analyst, Wells Fargo Securities LLC
# 87                  Analyst, Morgan Stanley & Co. LLC
# 88                              Analyst, Evercore ISI
# 89            Analyst, Deutsche Bank Securities, Inc.
# 90  Chairman & Chief Executive Officer, JPMorgan C...
#
#                                              Response  \
# 0   Yeah. Good question, John, and welcome back, b...
# 1   I do love what I do. And answering the second ...
# 2   Hey, Jim. I mean, it's obviously something we'...
# 3   Right, Erika. Okay. You are tempting me with m...
# 4   Very good. We can go to the next question. Tha...
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#                                      Response_cleaned      Executive  \
# 0   ['yeah good question john welcome back way so ...  Jeremy Barnum
# 1   ['love do answering second question first look...    Jamie Dimon
# 2   ['hey jim mean obviously something thinking lo...  Jeremy Barnum
# 3   ['right erika okay tempting many rabbit holes ...  Jeremy Barnum
# 4               ['good go next question thanks yeah']  Jeremy Barnum
# ..                                                ...            ...
# 86                                            ['nan']    Jamie Dimon
# 87                                            ['nan']  Jeremy Barnum
# 88                                            ['nan']  Jeremy Barnum
# 89                                            ['nan']  Jeremy Barnum
# 90                                            ['nan']        Unknown
#
#    Executive Role Type                                     Question_topic  \
# 0                  CFO  Based on the provided text, here are the disti...
# 1                  CEO  Based on the provided text, three distinct top...
# 2                  CFO  From the provided text, it seems to discuss to...
# 3                  CFO  1. **Topic Name: Capital Requirements and Regu...
# 4                  CFO  Based on the given text: "conclude question er...
# ..                 ...                                                ...
# 86           CEO & Co.         1. **Reintermediation in Lending Markets**
# 87           CFO & Co.  Analyzing the provided financial text, the fol...
# 88           CFO & Co.  Based on the analysis of the provided text, th...
# 89           CFO & Co.  Based on the provided financial text, there ar...
# 90             Unknown  The provided text, "excellent folks thank much...
#
#     ...                           Answer_topic_description  \
# 0   ...  1. **Strategic Financial Decisions & Capital A...
# 1   ...  1. **Succession Planning**: \n   - Example Sen...
# 2   ...  - Example Sentence: "we want a coherent, ratio...
# 3   ...  1. **Seasonality and G-SIB Metrics**\n   - **E...
# 4   ...  1. **General Conversation Closure or Transitio...
# ..  ...                                                ...
# 86  ...                          Description not available
# 87  ...                          Description not available
# 88  ...  Since the input does not contain any substanti...
# 89  ...                          Description not available
# 90  ...  Topic names and example sentences identificati...
#
#                                               Topic_1  \
# 0   **Strategic Financial Decisions & Capital Allo...
# 1   **Succession Planning**: \n   - Example Senten...
# 2   - Example Sentence: "we want a coherent, ratio...
# 3   **Seasonality and G-SIB Metrics**\n   - **Exam...
# 4   **General Conversation Closure or Transition**...
# ..                                                ...
# 86                          Description not available
# 87                          Description not available
# 88  Since the input does not contain any substanti...
# 89                          Description not available
# 90  Topic names and example sentences identificati...
#
#                                               Topic_2  \
# 0   **Investment Strategy and Focus Areas**:\n   -...
# 1   **Health Concerns and Rational Decisions**:\n ...
# 2   Topic Name: **Bank's Role and Operations**\n  ...
# 3   **Regulatory Reviews and Amendments**\n   - **...
# 4                                                 NaN
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88        **Topic Name**: Unavailable or Missing Data
# 89                                                NaN
# 90                                                NaN
#
#                                               Topic_3  \
# 0   **Operating Efficiency and Cost Management**:\...
# 1   **Public Perception and Media Interaction**:\n...
# 2   Topic Name: **Challenges to Bank Efficiency**\...
# 3   **Legal Actions and Industry Response**\n   - ...
# 4                                                 NaN
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88  **Example Sentence**: In the entire input text...
# 89                                                NaN
# 90                                                NaN
#
#                                               Topic_4  \
# 0   **Technological Modernization and Efficiency**...
# 1   **Talent Review and Internal Decision Making**...
# 2   Topic Name: **Capital Management and Basel III...
# 3   **Capital Requirements and Economic Growth**\n...
# 4                                                 NaN
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#                                               Topic_5  \
# 0   **Headcount Management and Organizational Effi...
# 1   **Uncertainty and Flexibility in Plans**:\n   ...
# 2   Topic Name: **Business Sentiment and Loan Grow...
# 3   **Scenario Analysis and Capital Projections**\...
# 4                                                 NaN
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#                                               Topic_6  \
# 0   **Critical Risk Management and Safety**:\n   -...
# 1   **Leadership Continuity and Company Stability*...
# 2   Topic Name: **Market Conditions and Business B...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
#
#                                               Topic_7 Topic_8 Topic_9
# 0                                                 NaN     NaN     NaN
# 1                                                 NaN     NaN     NaN
# 2   Topic Name: **Economic Optimism and its Realiz...     NaN     NaN
# 3                                                 NaN     NaN     NaN
# 4                                                 NaN     NaN     NaN
# ..                                                ...     ...     ...
# 86                                                NaN     NaN     NaN
# 87                                                NaN     NaN     NaN
# 88                                                NaN     NaN     NaN
# 89                                                NaN     NaN     NaN
# 90                                                NaN     NaN     NaN
#
# [91 rows x 22 columns]

# %%
############################################
# Step 6: Save Final DataFrame to CSV
############################################
print("Saving final DataFrame to CSV...")

final_df.to_csv("tqc_topic_model_jpmorgan_breakdown.csv", index=False)
print("CSV file saved successfully.")
# Out:
# Saving final DataFrame to CSV...
# CSV file saved successfully.

# %%
# Creating DataFrame
df = pd.DataFrame(final_df)

# Function to explode Topic column
def explode_topics(df):
    df = df.copy()
    df["Answer_topic_description"] = df["Answer_topic_description"].str.split(r'\s\d+\. ')
    df["Answer_topic_description"] = df["Answer_topic_description"].apply(lambda x: [i for i in x if i])
    return df.explode("Answer_topic_description", ignore_index=True)

# Applying function
df_exploded = explode_topics(df)

# Displaying the result
df_exploded
# Out:
#                            filename Quarter  \
# 0    1q23-earnings-call-remarks.pdf    1Q23
# 1    1q23-earnings-call-remarks.pdf    1Q23
# 2    1q23-earnings-call-remarks.pdf    1Q23
# 3    1q23-earnings-call-remarks.pdf    1Q23
# 4    1q23-earnings-call-remarks.pdf    1Q23
# ..                              ...     ...
# 276  4q24-earnings-call-remarks.pdf    4Q24
# 277  4q24-earnings-call-remarks.pdf    4Q24
# 278  4q24-earnings-call-remarks.pdf    4Q24
# 279  4q24-earnings-call-remarks.pdf    4Q24
# 280  4q24-earnings-call-remarks.pdf    4Q24
#
#                                               Question  \
# 0    Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1    Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 2    Yeah. Thanks. Just two questions. The first on...
# 3    Yeah. Thanks. Just two questions. The first on...
# 4    Yeah. Thank you. Good morning. Welcome back, S...
# ..                                                 ...
# 276  Good morning. It's Antonio from Bank of Americ...
# 277  Yes, good morning, everybody. I just got two f...
# 278  Yes, good morning, everybody. I just got two f...
# 279  Yes, good morning, everybody. I just got two f...
# 280  Yes, good morning, everybody. I just got two f...
#
#                                       Question_cleaned     Analyst_Bank  \
# 0    ['okay thank you capital requirements know sit...          Goldman
# 1    ['okay thank you capital requirements know sit...          Goldman
# 2    ['so sarah take first question take secondso g...         JPMorgan
# 3    ['so sarah take first question take secondso g...         JPMorgan
# 4    ['thank you ryan good back interact well look ...  Bank of America
# ..                                                 ...              ...
# 276  ['terms mitigants bit headwinds know definitel...  Bank of America
# 277  ['hi piers – take second question first terms ...             HSBC
# 278  ['hi piers – take second question first terms ...             HSBC
# 279  ['hi piers – take second question first terms ...             HSBC
# 280  ['hi piers – take second question first terms ...             HSBC
#
#                                               Response  \
# 0    Okay. Thank you. On capital requirements, you ...
# 1    Okay. Thank you. On capital requirements, you ...
# 2    So, Sarah, take the first question. I'll take ...
# 3    So, Sarah, take the first question. I'll take ...
# 4    Thank you, Ryan. It is good to be back to inte...
# ..                                                 ...
# 276  So in terms of the mitigants a bit to the head...
# 277  Hi Piers, so on – I'll just take your second q...
# 278  Hi Piers, so on – I'll just take your second q...
# 279  Hi Piers, so on – I'll just take your second q...
# 280  Hi Piers, so on – I'll just take your second q...
#
#                                       Response_cleaned  \
# 0    ['chis hallam goldman sachs yes good morning e...
# 1    ['chis hallam goldman sachs yes good morning e...
# 2    ['yeah thanks two questions first one related ...
# 3    ['yeah thanks two questions first one related ...
# 4    ['yeah thank you good morning welcome back ser...
# ..                                                 ...
# 276  ['good morning antonio bank america two questi...
# 277  ['yes good morning everybody got two follow-up...
# 278  ['yes good morning everybody got two follow-up...
# 279  ['yes good morning everybody got two follow-up...
# 280  ['yes good morning everybody got two follow-up...
#
#                                     Executive  \
# 0                       ['Sergio P. Ermotti']
# 1                       ['Sergio P. Ermotti']
# 2    ['Sergio P. Ermotti', 'Sarah Youngwood']
# 3    ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4                       ['Sergio P. Ermotti']
# ..                                        ...
# 276                          ['Todd Tuckner']
# 277     ['Todd Tuckner', 'Sergio P. Ermotti']
# 278     ['Todd Tuckner', 'Sergio P. Ermotti']
# 279     ['Todd Tuckner', 'Sergio P. Ermotti']
# 280     ['Todd Tuckner', 'Sergio P. Ermotti']
#
#                                         Question_topic  \
# 0             ### Topics Analysis from Financial Text:
# 1             ### Topics Analysis from Financial Text:
# 2    The provided financial text discusses multiple...
# 3    The provided financial text discusses multiple...
# 4    Based on the text provided, several distinct t...
# ..                                                 ...
# 276  From the provided text which seems to be part ...
# 277  Based on the provided text, the conversation a...
# 278  Based on the provided text, the conversation a...
# 279  Based on the provided text, the conversation a...
# 280  Based on the provided text, the conversation a...
#
#                             Question_topic_description  \
# 0    1. **Capital Requirements and Scope of Perimet...
# 1    1. **Capital Requirements and Scope of Perimet...
# 2    1. **Economic Impact Analysis**\n   - Example ...
# 3    1. **Economic Impact Analysis**\n   - Example ...
# 4    1. **Topic Name: Asset Management and Restruct...
# ..                                                 ...
# 276  1. **Revenue Growth and Hedging Strategies**\n...
# 277  1. **Basel III Impact and Internal Management*...
# 278  1. **Basel III Impact and Internal Management*...
# 279  1. **Basel III Impact and Internal Management*...
# 280  1. **Basel III Impact and Internal Management*...
#
#                                           Answer_topic  \
# 0                 ### 1. Topics discussed in the text:
# 1                 ### 1. Topics discussed in the text:
# 2    Based on the analysis of the provided financia...
# 3    Based on the analysis of the provided financia...
# 4    Based on the text provided, here are the topic...
# ..                                                 ...
# 276  The analyzed financial text discusses two main...
# 277  Based on the provided financial text, here are...
# 278  Based on the provided financial text, here are...
# 279  Based on the provided financial text, here are...
# 280  Based on the provided financial text, here are...
#
#                               Answer_topic_description
# 0    **Topic 1: Capital Requirements and Regulatory...
# 1    Additional Details from the Text:\n\nThe text ...
# 2    1. **Book Value Per Share Guidance:**\n   - Ex...
# 3    **Client Retention and Impact on Wealth Manage...
# 4    1. **Merger and Acquisition Strategy**\n   - *...
# ..                                                 ...
# 276  **NII Sensitivity and Hedging in Banking**\n  ...
# 277  1. **Client Risk Appetite and Banking Activity...
# 278  **Loan Portfolio and Credit Activity**:\n   - ...
# 279  **Regulatory Compliance - Basel III Impact**:\...
# 280  **Global Banking Pipeline Changes**:\n   - Exa...
#
# [281 rows x 12 columns]

# %%
df_exploded.to_csv("tqc_topic_model_ubs_breakdown1.csv", index=False)
print("CSV file saved successfully.")
# Out:
# CSV file saved successfully.
