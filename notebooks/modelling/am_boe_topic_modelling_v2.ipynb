# %% [markdown]
# <a href="https://colab.research.google.com/github/sheldonkemper/bank_of_england/blob/main/notebooks/modelling/am_boe_topic_modelling_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ############################################
# # Topic Modeling Using GPT-4-Turbo on Financial Text
# ############################################
# #
# # This script processes financial text data from CSV files using GPT-4-Turbo to identify topics discussed in the text.
# # It follows these steps:
# #
# # Step 1: Load the input CSV file into a pandas DataFrame.
# # Step 2: Define a function to interact with OpenAI GPT-4-Turbo to extract topics and their descriptions.
# # Step 3: Apply this function to the 'Question_cleand' column to create topic-related columns.
# # Step 4: Apply the same function to the 'Response_cleand' column.
# # Step 5: Save the final DataFrame to a CSV file.
# #
# # Required Libraries:
# # - openai: For interacting with GPT-4-Turbo.
# # - pandas: For handling data operations.
# # - os: For managing environment variables.
# ############################################

# %%
# Install required libraries (if not already installed)
# !pip install -q openai==0.28 2>&1
# !pip install -q pandas 2>&1
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.9 MB/s eta 0:00:00

# %%
# Import necessary libraries
import openai
import pandas as pd
import os
import re
import sys
from google.colab import drive

# Ensure OpenAI API key is set
openai.api_key = os.getenv("Openai_key")

# %%
# Mount Google Drive to the root location
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
############################################
# Step 1: Load CSV Files into DataFrame
############################################

# Load the CSV file (assuming the user uploads it)
input_df = pd.read_csv("/content/drive/MyDrive/BOE/bank_of_england/data/preprocessed_data/ubs_qa_df_preprocessed_ver2.csv")
print("CSV file loaded successfully.")
# Out:
# CSV file loaded successfully.

# %%
############################################
# Step 2: Define Function to Extract Topics using GPT-4-Turbo
############################################
print("Defining GPT-4-Turbo function for topic extraction...")

def extract_topics(text):
    """
    This function takes a financial text input and analyzes the topics discussed in the text.
    It returns a list of topics and corresponding sentences that contributed to each topic.
    """
    if pd.isna(text) or text.strip() == "":
        return "No Topic", "No Relevant Sentences"

    prompt = f"""
    Analyze the following financial text and extract distinct topics discussed.
    Provide:
    1. The topic names.
    2. Example sentences that helped you identify the topic.

    Text:
    {text}
    """

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4-turbo",
            messages=[{"role": "user", "content": prompt}]
        )

        result = response["choices"][0]["message"]["content"]

        # Splitting response into topic and description
        if "\n" in result:
            parts = result.split("\n", 1)
            topic = parts[0].strip()
            topic_description = parts[1].strip()
        else:
            topic = result.strip()
            topic_description = "Description not available"

        return topic, topic_description
    except Exception as e:
        return "Error", str(e)
# Out:
# Defining GPT-4-Turbo function for topic extraction...

# %%
############################################
# Step 3: Apply Function to 'Question_cleand' Column
############################################

input_df[['Question_topic', 'Question_topic_description']] = input_df['Question_cleaned'].apply(
    lambda x: pd.Series(extract_topics(x))
)

question_df = input_df.copy()
print("Topic extraction for questions completed.")
# Out:
# Topic extraction for questions completed.

# %%
question_df
# Out:
#                           filename Quarter  \
# 0   1q23-earnings-call-remarks.pdf    1Q23
# 1   1q23-earnings-call-remarks.pdf    1Q23
# 2   1q23-earnings-call-remarks.pdf    1Q23
# 3   1q23-earnings-call-remarks.pdf    1Q23
# 4   1q23-earnings-call-remarks.pdf    1Q23
# ..                             ...     ...
# 91  4q24-earnings-call-remarks.pdf    4Q24
# 92  4q24-earnings-call-remarks.pdf    4Q24
# 93  4q24-earnings-call-remarks.pdf    4Q24
# 94  4q24-earnings-call-remarks.pdf    4Q24
# 95  4q24-earnings-call-remarks.pdf    4Q24
#
#                                              Question  \
# 0   Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1   Yeah. Thanks. Just two questions. The first on...
# 2   Yeah. Thank you. Good morning. Welcome back, S...
# 3   Yes. Good morning. The first question I wanted...
# 4   Good morning. Two questions. Firstly, just on ...
# ..                                                ...
# 91  Good morning. One follow-up on GWM Americas an...
# 92                 Very helpful. Thank you very much.
# 93  Hi. Thank you and thank you for the clarificat...
# 94  Good morning. It's Antonio from Bank of Americ...
# 95  Yes, good morning, everybody. I just got two f...
#
#                                      Question_cleaned         Analyst_Bank  \
# 0   ['okay thank you capital requirements know sit...              Goldman
# 1   ['so sarah take first question take secondso g...             JPMorgan
# 2   ['thank you ryan good back interact well look ...      Bank of America
# 3   ['so first question terms trends april really ...            Jefferies
# 4   ['so first quarter first question seen signifi...                 Citi
# ..                                                ...                  ...
# 91  ['first first question respect fa comp changes...                 Citi
# 92                                               ['']  Autonomous Research
# 93  ['yeah terms expectations really articulated s...           Mediobanca
# 94  ['terms mitigants bit headwinds know definitel...      Bank of America
# 95  ['hi piers – take second question first terms ...                 HSBC
#
#                                              Response  \
# 0   Okay. Thank you. On capital requirements, you ...
# 1   So, Sarah, take the first question. I'll take ...
# 2   Thank you, Ryan. It is good to be back to inte...
# 3   So, on the first question in terms of the tren...
# 4   So, on the first quarter or the first question...
# ..                                                ...
# 91  So first, on your first question in respect to...
# 92                                                NaN
# 93  Yeah. So in terms of the expectations, we have...
# 94  So in terms of the mitigants a bit to the head...
# 95  Hi Piers, so on – I'll just take your second q...
#
#                                      Response_cleaned  \
# 0   ['chis hallam goldman sachs yes good morning e...
# 1   ['yeah thanks two questions first one related ...
# 2   ['yeah thank you good morning welcome back ser...
# 3   ['yes good morning first question wanted ask r...
# 4   ['good morning two questions firstly slide 10 ...
# ..                                                ...
# 91  ['good morning one follow-up gwm americas perh...
# 92                             ['helpful thank much']
# 93  ['hi thank thank clarifications capital got co...
# 94  ['good morning antonio bank america two questi...
# 95  ['yes good morning everybody got two follow-up...
#
#                                    Executive  \
# 0                      ['Sergio P. Ermotti']
# 1   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 2                      ['Sergio P. Ermotti']
# 3   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4                        ['Sarah Youngwood']
# ..                                       ...
# 91                          ['Todd Tuckner']
# 92                                        []
# 93                          ['Todd Tuckner']
# 94                          ['Todd Tuckner']
# 95     ['Todd Tuckner', 'Sergio P. Ermotti']
#
#                                        Question_topic  \
# 0   Based on the provided financial text, I can ex...
# 1   From the provided financial text, the topics d...
# 2   Based on the provided text, here are two disti...
# 3   Based on the analysis of the text, the topics ...
# 4   From the provided text, several financial topi...
# ..                                                ...
# 91  Sure, I’ve analyzed the provided financial tex...
# 92  It seems like there was an issue, and no text ...
# 93  The financial text provided discusses several ...
# 94  The given financial text discusses a range of ...
# 95  The financial text provided discusses several ...
#
#                            Question_topic_description
# 0   1. **Capital Requirements and Operational Risk...
# 1   1. **Economic Impact and Financial Metrics**:\...
# 2   1. **Topic Name: Asset Management Strategy**\n...
# 3   1. **Market Trends and Client Behavior:**\n   ...
# 4   1. **Mix Shifts in Financial Products and Depo...
# ..                                                ...
# 91  1. **Compensation Model Changes:**\n   - **Exa...
# 92                          Description not available
# 93  1. **Financial Performance Expectations:**\n  ...
# 94  1. **Non-Interest Income and Revenue Growth**:...
# 95  ### 1. **Basel III Compliance and Strategic Ad...
#
# [96 rows x 10 columns]

# %%
############################################
# Step 4: Apply Function to 'Response_cleand' Column
############################################
print("Applying GPT-4-Turbo function on 'Response_cleand' column...")

question_df[['Answer_topic', 'Answer_topic_description']] = question_df['Response_cleaned'].apply(
    lambda x: pd.Series(extract_topics(x))
)

final_df = question_df.copy()
print("Topic extraction for responses completed.")
# Out:
# Applying GPT-4-Turbo function on 'Response_cleand' column...
# Topic extraction for responses completed.

# %%
final_df
# Out:
#                           filename Quarter  \
# 0   1q23-earnings-call-remarks.pdf    1Q23
# 1   1q23-earnings-call-remarks.pdf    1Q23
# 2   1q23-earnings-call-remarks.pdf    1Q23
# 3   1q23-earnings-call-remarks.pdf    1Q23
# 4   1q23-earnings-call-remarks.pdf    1Q23
# ..                             ...     ...
# 91  4q24-earnings-call-remarks.pdf    4Q24
# 92  4q24-earnings-call-remarks.pdf    4Q24
# 93  4q24-earnings-call-remarks.pdf    4Q24
# 94  4q24-earnings-call-remarks.pdf    4Q24
# 95  4q24-earnings-call-remarks.pdf    4Q24
#
#                                              Question  \
# 0   Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1   Yeah. Thanks. Just two questions. The first on...
# 2   Yeah. Thank you. Good morning. Welcome back, S...
# 3   Yes. Good morning. The first question I wanted...
# 4   Good morning. Two questions. Firstly, just on ...
# ..                                                ...
# 91  Good morning. One follow-up on GWM Americas an...
# 92                 Very helpful. Thank you very much.
# 93  Hi. Thank you and thank you for the clarificat...
# 94  Good morning. It's Antonio from Bank of Americ...
# 95  Yes, good morning, everybody. I just got two f...
#
#                                      Question_cleaned         Analyst_Bank  \
# 0   ['okay thank you capital requirements know sit...              Goldman
# 1   ['so sarah take first question take secondso g...             JPMorgan
# 2   ['thank you ryan good back interact well look ...      Bank of America
# 3   ['so first question terms trends april really ...            Jefferies
# 4   ['so first quarter first question seen signifi...                 Citi
# ..                                                ...                  ...
# 91  ['first first question respect fa comp changes...                 Citi
# 92                                               ['']  Autonomous Research
# 93  ['yeah terms expectations really articulated s...           Mediobanca
# 94  ['terms mitigants bit headwinds know definitel...      Bank of America
# 95  ['hi piers – take second question first terms ...                 HSBC
#
#                                              Response  \
# 0   Okay. Thank you. On capital requirements, you ...
# 1   So, Sarah, take the first question. I'll take ...
# 2   Thank you, Ryan. It is good to be back to inte...
# 3   So, on the first question in terms of the tren...
# 4   So, on the first quarter or the first question...
# ..                                                ...
# 91  So first, on your first question in respect to...
# 92                                                NaN
# 93  Yeah. So in terms of the expectations, we have...
# 94  So in terms of the mitigants a bit to the head...
# 95  Hi Piers, so on – I'll just take your second q...
#
#                                      Response_cleaned  \
# 0   ['chis hallam goldman sachs yes good morning e...
# 1   ['yeah thanks two questions first one related ...
# 2   ['yeah thank you good morning welcome back ser...
# 3   ['yes good morning first question wanted ask r...
# 4   ['good morning two questions firstly slide 10 ...
# ..                                                ...
# 91  ['good morning one follow-up gwm americas perh...
# 92                             ['helpful thank much']
# 93  ['hi thank thank clarifications capital got co...
# 94  ['good morning antonio bank america two questi...
# 95  ['yes good morning everybody got two follow-up...
#
#                                    Executive  \
# 0                      ['Sergio P. Ermotti']
# 1   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 2                      ['Sergio P. Ermotti']
# 3   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4                        ['Sarah Youngwood']
# ..                                       ...
# 91                          ['Todd Tuckner']
# 92                                        []
# 93                          ['Todd Tuckner']
# 94                          ['Todd Tuckner']
# 95     ['Todd Tuckner', 'Sergio P. Ermotti']
#
#                                        Question_topic  \
# 0   Based on the provided financial text, I can ex...
# 1   From the provided financial text, the topics d...
# 2   Based on the provided text, here are two disti...
# 3   Based on the analysis of the text, the topics ...
# 4   From the provided text, several financial topi...
# ..                                                ...
# 91  Sure, I’ve analyzed the provided financial tex...
# 92  It seems like there was an issue, and no text ...
# 93  The financial text provided discusses several ...
# 94  The given financial text discusses a range of ...
# 95  The financial text provided discusses several ...
#
#                            Question_topic_description  \
# 0   1. **Capital Requirements and Operational Risk...
# 1   1. **Economic Impact and Financial Metrics**:\...
# 2   1. **Topic Name: Asset Management Strategy**\n...
# 3   1. **Market Trends and Client Behavior:**\n   ...
# 4   1. **Mix Shifts in Financial Products and Depo...
# ..                                                ...
# 91  1. **Compensation Model Changes:**\n   - **Exa...
# 92                          Description not available
# 93  1. **Financial Performance Expectations:**\n  ...
# 94  1. **Non-Interest Income and Revenue Growth**:...
# 95  ### 1. **Basel III Compliance and Strategic Ad...
#
#                                          Answer_topic  \
# 0   The text in question discusses two prominent t...
# 1   From the provided financial text, here are the...
# 2   From the provided financial text, I identified...
# 3   The provided text discusses two main financial...
# 4           1. **Net Interest Income (NII) Forecast**
# ..                                                ...
# 91  From the given text, I can identify two main t...
# 92  Based on the given text, "['helpful thank much...
# 93         ### Extracted Topics and Example Sentences
# 94  ### Topic Analysis from the Provided Financial...
# 95               **1. Analysis of Financial Topics:**
#
#                              Answer_topic_description
# 0   1. **Capital Requirements for Banks:**\n   - *...
# 1   1. **Book Value Per Share Guidance**\n   - Top...
# 2   1. **Merger and Consolidation Impact**\n   - *...
# 3   1. **Net New Money and Client Behavior Trends*...
# 4   - Example sentence: "Focusing on your revised ...
# ..                                                ...
# 91  ### Topic 1: Changes in Financial Advisor Ince...
# 92  1. **General Gratitude or Acknowledgment** - T...
# 93  1. **Profitability Targets and Margins**\n   -...
# 94  #### Topic 1: Capital Management and Financial...
# 95  **Topic 1: Client Risk Appetite and Financial ...
#
# [96 rows x 12 columns]

# %%
############################################
# Step 5: Save Final DataFrame to CSV
############################################
print("Saving final DataFrame to CSV...")

final_df.to_csv("/content/drive/MyDrive/BOE/bank_of_england/data/model_outputs/Topic_Modelling_am/Final topic model/tqc_topic_model_jpmorgan.csv", index=False)
print("CSV file saved successfully.")
# Out:
# Saving final DataFrame to CSV...
# CSV file saved successfully.

# %%
# Function to split topics and expand rows
def split_topics(row):
    topics = re.split(r'\n?\d+\.\s\*\*(.*?)\*\*:', row['Answer_topic_description'])
    topics = [t.strip() for t in topics if t.strip()]  # Remove empty entries
    return pd.DataFrame([{**row, 'Answer_topic_description': t} for t in topics])

# Apply the function to each row and reset the index
expanded_df = pd.concat([split_topics(row) for _, row in final_df.iterrows()], ignore_index=True)

# Display the processed DataFrame
expanded_df
# Out:
#                            filename Quarter  \
# 0    1q23-earnings-call-remarks.pdf    1Q23
# 1    1q23-earnings-call-remarks.pdf    1Q23
# 2    1q23-earnings-call-remarks.pdf    1Q23
# 3    1q23-earnings-call-remarks.pdf    1Q23
# 4    1q23-earnings-call-remarks.pdf    1Q23
# ..                              ...     ...
# 150  4q24-earnings-call-remarks.pdf    4Q24
# 151  4q24-earnings-call-remarks.pdf    4Q24
# 152  4q24-earnings-call-remarks.pdf    4Q24
# 153  4q24-earnings-call-remarks.pdf    4Q24
# 154  4q24-earnings-call-remarks.pdf    4Q24
#
#                                               Question  \
# 0    Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1    Yeah. Thanks. Just two questions. The first on...
# 2    Yeah. Thank you. Good morning. Welcome back, S...
# 3    Yes. Good morning. The first question I wanted...
# 4    Yes. Good morning. The first question I wanted...
# ..                                                 ...
# 150  Good morning. One follow-up on GWM Americas an...
# 151                 Very helpful. Thank you very much.
# 152  Hi. Thank you and thank you for the clarificat...
# 153  Good morning. It's Antonio from Bank of Americ...
# 154  Yes, good morning, everybody. I just got two f...
#
#                                       Question_cleaned         Analyst_Bank  \
# 0    ['okay thank you capital requirements know sit...              Goldman
# 1    ['so sarah take first question take secondso g...             JPMorgan
# 2    ['thank you ryan good back interact well look ...      Bank of America
# 3    ['so first question terms trends april really ...            Jefferies
# 4    ['so first question terms trends april really ...            Jefferies
# ..                                                 ...                  ...
# 150  ['first first question respect fa comp changes...                 Citi
# 151                                               ['']  Autonomous Research
# 152  ['yeah terms expectations really articulated s...           Mediobanca
# 153  ['terms mitigants bit headwinds know definitel...      Bank of America
# 154  ['hi piers – take second question first terms ...                 HSBC
#
#                                               Response  \
# 0    Okay. Thank you. On capital requirements, you ...
# 1    So, Sarah, take the first question. I'll take ...
# 2    Thank you, Ryan. It is good to be back to inte...
# 3    So, on the first question in terms of the tren...
# 4    So, on the first question in terms of the tren...
# ..                                                 ...
# 150  So first, on your first question in respect to...
# 151                                                NaN
# 152  Yeah. So in terms of the expectations, we have...
# 153  So in terms of the mitigants a bit to the head...
# 154  Hi Piers, so on – I'll just take your second q...
#
#                                       Response_cleaned  \
# 0    ['chis hallam goldman sachs yes good morning e...
# 1    ['yeah thanks two questions first one related ...
# 2    ['yeah thank you good morning welcome back ser...
# 3    ['yes good morning first question wanted ask r...
# 4    ['yes good morning first question wanted ask r...
# ..                                                 ...
# 150  ['good morning one follow-up gwm americas perh...
# 151                             ['helpful thank much']
# 152  ['hi thank thank clarifications capital got co...
# 153  ['good morning antonio bank america two questi...
# 154  ['yes good morning everybody got two follow-up...
#
#                                     Executive  \
# 0                       ['Sergio P. Ermotti']
# 1    ['Sergio P. Ermotti', 'Sarah Youngwood']
# 2                       ['Sergio P. Ermotti']
# 3    ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4    ['Sergio P. Ermotti', 'Sarah Youngwood']
# ..                                        ...
# 150                          ['Todd Tuckner']
# 151                                        []
# 152                          ['Todd Tuckner']
# 153                          ['Todd Tuckner']
# 154     ['Todd Tuckner', 'Sergio P. Ermotti']
#
#                                         Question_topic  \
# 0    Based on the provided financial text, I can ex...
# 1    From the provided financial text, the topics d...
# 2    Based on the provided text, here are two disti...
# 3    Based on the analysis of the text, the topics ...
# 4    Based on the analysis of the text, the topics ...
# ..                                                 ...
# 150  Sure, I’ve analyzed the provided financial tex...
# 151  It seems like there was an issue, and no text ...
# 152  The financial text provided discusses several ...
# 153  The given financial text discusses a range of ...
# 154  The financial text provided discusses several ...
#
#                             Question_topic_description  \
# 0    1. **Capital Requirements and Operational Risk...
# 1    1. **Economic Impact and Financial Metrics**:\...
# 2    1. **Topic Name: Asset Management Strategy**\n...
# 3    1. **Market Trends and Client Behavior:**\n   ...
# 4    1. **Market Trends and Client Behavior:**\n   ...
# ..                                                 ...
# 150  1. **Compensation Model Changes:**\n   - **Exa...
# 151                          Description not available
# 152  1. **Financial Performance Expectations:**\n  ...
# 153  1. **Non-Interest Income and Revenue Growth**:...
# 154  ### 1. **Basel III Compliance and Strategic Ad...
#
#                                           Answer_topic  \
# 0    The text in question discusses two prominent t...
# 1    From the provided financial text, here are the...
# 2    From the provided financial text, I identified...
# 3    The provided text discusses two main financial...
# 4    The provided text discusses two main financial...
# ..                                                 ...
# 150  From the given text, I can identify two main t...
# 151  Based on the given text, "['helpful thank much...
# 152         ### Extracted Topics and Example Sentences
# 153  ### Topic Analysis from the Provided Financial...
# 154               **1. Analysis of Financial Topics:**
#
#                               Answer_topic_description
# 0    1. **Capital Requirements for Banks:**\n   - *...
# 1    1. **Book Value Per Share Guidance**\n   - Top...
# 2    1. **Merger and Consolidation Impact**\n   - *...
# 3             Net New Money and Client Behavior Trends
# 4    - Example sentence: "first question wanted ask...
# ..                                                 ...
# 150  ### Topic 1: Changes in Financial Advisor Ince...
# 151  1. **General Gratitude or Acknowledgment** - T...
# 152  1. **Profitability Targets and Margins**\n   -...
# 153  #### Topic 1: Capital Management and Financial...
# 154  **Topic 1: Client Risk Appetite and Financial ...
#
# [155 rows x 12 columns]

# %%
# Function to extract topics and reformat the row
def extract_topics(row):
    # Splitting based on numbered pattern (1, 2, 3, etc.) while keeping the content
    sections = re.split(r'\n?\d+\.\s', row['Answer_topic_description'])
    sections = [s.strip() for s in sections if s.strip()]  # Remove empty entries

    # Create a new dictionary for the reformatted row
    new_row = row.to_dict()

    # Assign each section to a new numbered column
    for i, section in enumerate(sections):
        new_row[f"Topic_{i+1}"] = section  # Naming columns as Topic_1, Topic_2, etc.

    return new_row

# Apply the function and expand the DataFrame
expanded_df = pd.DataFrame([extract_topics(row) for _, row in final_df.iterrows()])

# Display the processed DataFrame
expanded_df
# Out:
#                           filename Quarter  \
# 0   1q23-earnings-call-remarks.pdf    1Q23
# 1   1q23-earnings-call-remarks.pdf    1Q23
# 2   1q23-earnings-call-remarks.pdf    1Q23
# 3   1q23-earnings-call-remarks.pdf    1Q23
# 4   1q23-earnings-call-remarks.pdf    1Q23
# ..                             ...     ...
# 91  4q24-earnings-call-remarks.pdf    4Q24
# 92  4q24-earnings-call-remarks.pdf    4Q24
# 93  4q24-earnings-call-remarks.pdf    4Q24
# 94  4q24-earnings-call-remarks.pdf    4Q24
# 95  4q24-earnings-call-remarks.pdf    4Q24
#
#                                              Question  \
# 0   Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1   Yeah. Thanks. Just two questions. The first on...
# 2   Yeah. Thank you. Good morning. Welcome back, S...
# 3   Yes. Good morning. The first question I wanted...
# 4   Good morning. Two questions. Firstly, just on ...
# ..                                                ...
# 91  Good morning. One follow-up on GWM Americas an...
# 92                 Very helpful. Thank you very much.
# 93  Hi. Thank you and thank you for the clarificat...
# 94  Good morning. It's Antonio from Bank of Americ...
# 95  Yes, good morning, everybody. I just got two f...
#
#                                      Question_cleaned         Analyst_Bank  \
# 0   ['okay thank you capital requirements know sit...              Goldman
# 1   ['so sarah take first question take secondso g...             JPMorgan
# 2   ['thank you ryan good back interact well look ...      Bank of America
# 3   ['so first question terms trends april really ...            Jefferies
# 4   ['so first quarter first question seen signifi...                 Citi
# ..                                                ...                  ...
# 91  ['first first question respect fa comp changes...                 Citi
# 92                                               ['']  Autonomous Research
# 93  ['yeah terms expectations really articulated s...           Mediobanca
# 94  ['terms mitigants bit headwinds know definitel...      Bank of America
# 95  ['hi piers – take second question first terms ...                 HSBC
#
#                                              Response  \
# 0   Okay. Thank you. On capital requirements, you ...
# 1   So, Sarah, take the first question. I'll take ...
# 2   Thank you, Ryan. It is good to be back to inte...
# 3   So, on the first question in terms of the tren...
# 4   So, on the first quarter or the first question...
# ..                                                ...
# 91  So first, on your first question in respect to...
# 92                                                NaN
# 93  Yeah. So in terms of the expectations, we have...
# 94  So in terms of the mitigants a bit to the head...
# 95  Hi Piers, so on – I'll just take your second q...
#
#                                      Response_cleaned  \
# 0   ['chis hallam goldman sachs yes good morning e...
# 1   ['yeah thanks two questions first one related ...
# 2   ['yeah thank you good morning welcome back ser...
# 3   ['yes good morning first question wanted ask r...
# 4   ['good morning two questions firstly slide 10 ...
# ..                                                ...
# 91  ['good morning one follow-up gwm americas perh...
# 92                             ['helpful thank much']
# 93  ['hi thank thank clarifications capital got co...
# 94  ['good morning antonio bank america two questi...
# 95  ['yes good morning everybody got two follow-up...
#
#                                    Executive  \
# 0                      ['Sergio P. Ermotti']
# 1   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 2                      ['Sergio P. Ermotti']
# 3   ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4                        ['Sarah Youngwood']
# ..                                       ...
# 91                          ['Todd Tuckner']
# 92                                        []
# 93                          ['Todd Tuckner']
# 94                          ['Todd Tuckner']
# 95     ['Todd Tuckner', 'Sergio P. Ermotti']
#
#                                        Question_topic  \
# 0   Based on the provided financial text, I can ex...
# 1   From the provided financial text, the topics d...
# 2   Based on the provided text, here are two disti...
# 3   Based on the analysis of the text, the topics ...
# 4   From the provided text, several financial topi...
# ..                                                ...
# 91  Sure, I’ve analyzed the provided financial tex...
# 92  It seems like there was an issue, and no text ...
# 93  The financial text provided discusses several ...
# 94  The given financial text discusses a range of ...
# 95  The financial text provided discusses several ...
#
#                            Question_topic_description  \
# 0   1. **Capital Requirements and Operational Risk...
# 1   1. **Economic Impact and Financial Metrics**:\...
# 2   1. **Topic Name: Asset Management Strategy**\n...
# 3   1. **Market Trends and Client Behavior:**\n   ...
# 4   1. **Mix Shifts in Financial Products and Depo...
# ..                                                ...
# 91  1. **Compensation Model Changes:**\n   - **Exa...
# 92                          Description not available
# 93  1. **Financial Performance Expectations:**\n  ...
# 94  1. **Non-Interest Income and Revenue Growth**:...
# 95  ### 1. **Basel III Compliance and Strategic Ad...
#
#                                          Answer_topic  \
# 0   The text in question discusses two prominent t...
# 1   From the provided financial text, here are the...
# 2   From the provided financial text, I identified...
# 3   The provided text discusses two main financial...
# 4           1. **Net Interest Income (NII) Forecast**
# ..                                                ...
# 91  From the given text, I can identify two main t...
# 92  Based on the given text, "['helpful thank much...
# 93         ### Extracted Topics and Example Sentences
# 94  ### Topic Analysis from the Provided Financial...
# 95               **1. Analysis of Financial Topics:**
#
#                              Answer_topic_description  \
# 0   1. **Capital Requirements for Banks:**\n   - *...
# 1   1. **Book Value Per Share Guidance**\n   - Top...
# 2   1. **Merger and Consolidation Impact**\n   - *...
# 3   1. **Net New Money and Client Behavior Trends*...
# 4   - Example sentence: "Focusing on your revised ...
# ..                                                ...
# 91  ### Topic 1: Changes in Financial Advisor Ince...
# 92  1. **General Gratitude or Acknowledgment** - T...
# 93  1. **Profitability Targets and Margins**\n   -...
# 94  #### Topic 1: Capital Management and Financial...
# 95  **Topic 1: Client Risk Appetite and Financial ...
#
#                                               Topic_1  \
# 0   **Capital Requirements for Banks:**\n   - **Ex...
# 1   **Book Value Per Share Guidance**\n   - Topic ...
# 2   **Merger and Consolidation Impact**\n   - **Ex...
# 3   **Net New Money and Client Behavior Trends**:\...
# 4   - Example sentence: "Focusing on your revised ...
# ..                                                ...
# 91  ### Topic 1: Changes in Financial Advisor Ince...
# 92  **General Gratitude or Acknowledgment** - This...
# 93  **Profitability Targets and Margins**\n   - Ex...
# 94  #### Topic 1: Capital Management and Financial...
# 95  **Topic 1: Client Risk Appetite and Financial ...
#
#                                               Topic_2  \
# 0   **Loss Sharing Agreement and Legislative Appro...
# 1   **Accounting for Acquisitions**\n   - Topic In...
# 2   **Strong Capital Position and Financial Strate...
# 3   **Risk Concentration and Client Segment Impact...
# 4   **Deposit Migration and Rate Hikes**\n   - Exa...
# ..                                                ...
# 91                                                NaN
# 92  Example sentence: "helpful thank much" - This ...
# 93  **Comparison with Peers** \n   - Example Sente...
# 94                                                NaN
# 95                                                NaN
#
#                                               Topic_3  \
# 0                                                 NaN
# 1   **Client Retention in Wealth Management**\n   ...
# 2   **Future Plans and Restructuring**\n   - **Exa...
# 3                                                 NaN
# 4   **Liquidity Coverage Ratio (LCR) and Regulatio...
# ..                                                ...
# 91                                                NaN
# 92                                                NaN
# 93  **Investment Strategy**\n   - Example Sentence...
# 94                                                NaN
# 95                                                NaN
#
#                                               Topic_4  \
# 0                                                 NaN
# 1   **Financial Impact and Reporting**\n   - Topic...
# 2                                                 NaN
# 3                                                 NaN
# 4   **Strategic Financial Management**\n   - Examp...
# ..                                                ...
# 91                                                NaN
# 92                                                NaN
# 93  **Long-term Sustainability**\n   - Example Sen...
# 94                                                NaN
# 95                                                NaN
#
#                                               Topic_5 Topic_6
# 0                                                 NaN     NaN
# 1                                                 NaN     NaN
# 2                                                 NaN     NaN
# 3                                                 NaN     NaN
# 4                                                 NaN     NaN
# ..                                                ...     ...
# 91                                                NaN     NaN
# 92                                                NaN     NaN
# 93  **Ongoing Investment Requirements**\n   - Exam...     NaN
# 94                                                NaN     NaN
# 95                                                NaN     NaN
#
# [96 rows x 18 columns]

# %%
############################################
# Step 6: Save Final DataFrame to CSV
############################################
print("Saving final DataFrame to CSV...")

final_df.to_csv("/content/drive/MyDrive/BOE/bank_of_england/data/model_outputs/Topic_Modelling_am/Final topic model/tqc_topic_model_jpmorgan_breakdown.csv", index=False)
print("CSV file saved successfully.")
# Out:
# Saving final DataFrame to CSV...
# CSV file saved successfully.

# %%
# Creating DataFrame
df = pd.DataFrame(final_df)

# Function to explode Topic column
def explode_topics(df):
    df = df.copy()
    df["Answer_topic_description"] = df["Answer_topic_description"].str.split(r'\s\d+\. ')
    df["Answer_topic_description"] = df["Answer_topic_description"].apply(lambda x: [i for i in x if i])
    return df.explode("Answer_topic_description", ignore_index=True)

# Applying function
df_exploded = explode_topics(df)

# Displaying the result
df_exploded
# Out:
#                            filename Quarter  \
# 0    1q23-earnings-call-remarks.pdf    1Q23
# 1    1q23-earnings-call-remarks.pdf    1Q23
# 2    1q23-earnings-call-remarks.pdf    1Q23
# 3    1q23-earnings-call-remarks.pdf    1Q23
# 4    1q23-earnings-call-remarks.pdf    1Q23
# ..                              ...     ...
# 252  4q24-earnings-call-remarks.pdf    4Q24
# 253  4q24-earnings-call-remarks.pdf    4Q24
# 254  4q24-earnings-call-remarks.pdf    4Q24
# 255  4q24-earnings-call-remarks.pdf    4Q24
# 256  4q24-earnings-call-remarks.pdf    4Q24
#
#                                               Question  \
# 0    Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 1    Chis Hallam, Goldman Sachs Yes. Good morning, ...
# 2    Yeah. Thanks. Just two questions. The first on...
# 3    Yeah. Thanks. Just two questions. The first on...
# 4    Yeah. Thanks. Just two questions. The first on...
# ..                                                 ...
# 252  Hi. Thank you and thank you for the clarificat...
# 253  Hi. Thank you and thank you for the clarificat...
# 254  Hi. Thank you and thank you for the clarificat...
# 255  Good morning. It's Antonio from Bank of Americ...
# 256  Yes, good morning, everybody. I just got two f...
#
#                                       Question_cleaned     Analyst_Bank  \
# 0    ['okay thank you capital requirements know sit...          Goldman
# 1    ['okay thank you capital requirements know sit...          Goldman
# 2    ['so sarah take first question take secondso g...         JPMorgan
# 3    ['so sarah take first question take secondso g...         JPMorgan
# 4    ['so sarah take first question take secondso g...         JPMorgan
# ..                                                 ...              ...
# 252  ['yeah terms expectations really articulated s...       Mediobanca
# 253  ['yeah terms expectations really articulated s...       Mediobanca
# 254  ['yeah terms expectations really articulated s...       Mediobanca
# 255  ['terms mitigants bit headwinds know definitel...  Bank of America
# 256  ['hi piers – take second question first terms ...             HSBC
#
#                                               Response  \
# 0    Okay. Thank you. On capital requirements, you ...
# 1    Okay. Thank you. On capital requirements, you ...
# 2    So, Sarah, take the first question. I'll take ...
# 3    So, Sarah, take the first question. I'll take ...
# 4    So, Sarah, take the first question. I'll take ...
# ..                                                 ...
# 252  Yeah. So in terms of the expectations, we have...
# 253  Yeah. So in terms of the expectations, we have...
# 254  Yeah. So in terms of the expectations, we have...
# 255  So in terms of the mitigants a bit to the head...
# 256  Hi Piers, so on – I'll just take your second q...
#
#                                       Response_cleaned  \
# 0    ['chis hallam goldman sachs yes good morning e...
# 1    ['chis hallam goldman sachs yes good morning e...
# 2    ['yeah thanks two questions first one related ...
# 3    ['yeah thanks two questions first one related ...
# 4    ['yeah thanks two questions first one related ...
# ..                                                 ...
# 252  ['hi thank thank clarifications capital got co...
# 253  ['hi thank thank clarifications capital got co...
# 254  ['hi thank thank clarifications capital got co...
# 255  ['good morning antonio bank america two questi...
# 256  ['yes good morning everybody got two follow-up...
#
#                                     Executive  \
# 0                       ['Sergio P. Ermotti']
# 1                       ['Sergio P. Ermotti']
# 2    ['Sergio P. Ermotti', 'Sarah Youngwood']
# 3    ['Sergio P. Ermotti', 'Sarah Youngwood']
# 4    ['Sergio P. Ermotti', 'Sarah Youngwood']
# ..                                        ...
# 252                          ['Todd Tuckner']
# 253                          ['Todd Tuckner']
# 254                          ['Todd Tuckner']
# 255                          ['Todd Tuckner']
# 256     ['Todd Tuckner', 'Sergio P. Ermotti']
#
#                                         Question_topic  \
# 0    Based on the provided financial text, I can ex...
# 1    Based on the provided financial text, I can ex...
# 2    From the provided financial text, the topics d...
# 3    From the provided financial text, the topics d...
# 4    From the provided financial text, the topics d...
# ..                                                 ...
# 252  The financial text provided discusses several ...
# 253  The financial text provided discusses several ...
# 254  The financial text provided discusses several ...
# 255  The given financial text discusses a range of ...
# 256  The financial text provided discusses several ...
#
#                             Question_topic_description  \
# 0    1. **Capital Requirements and Operational Risk...
# 1    1. **Capital Requirements and Operational Risk...
# 2    1. **Economic Impact and Financial Metrics**:\...
# 3    1. **Economic Impact and Financial Metrics**:\...
# 4    1. **Economic Impact and Financial Metrics**:\...
# ..                                                 ...
# 252  1. **Financial Performance Expectations:**\n  ...
# 253  1. **Financial Performance Expectations:**\n  ...
# 254  1. **Financial Performance Expectations:**\n  ...
# 255  1. **Non-Interest Income and Revenue Growth**:...
# 256  ### 1. **Basel III Compliance and Strategic Ad...
#
#                                           Answer_topic  \
# 0    The text in question discusses two prominent t...
# 1    The text in question discusses two prominent t...
# 2    From the provided financial text, here are the...
# 3    From the provided financial text, here are the...
# 4    From the provided financial text, here are the...
# ..                                                 ...
# 252         ### Extracted Topics and Example Sentences
# 253         ### Extracted Topics and Example Sentences
# 254         ### Extracted Topics and Example Sentences
# 255  ### Topic Analysis from the Provided Financial...
# 256               **1. Analysis of Financial Topics:**
#
#                               Answer_topic_description
# 0    1. **Capital Requirements for Banks:**\n   - *...
# 1    **Loss Sharing Agreement and Legislative Appro...
# 2    1. **Book Value Per Share Guidance**\n   - Top...
# 3    **Accounting for Acquisitions**\n   - Topic In...
# 4    **Client Retention in Wealth Management**\n   ...
# ..                                                 ...
# 252  **Investment Strategy**\n   - Example Sentence...
# 253  **Long-term Sustainability**\n   - Example Sen...
# 254  **Ongoing Investment Requirements**\n   - Exam...
# 255  #### Topic 1: Capital Management and Financial...
# 256  **Topic 1: Client Risk Appetite and Financial ...
#
# [257 rows x 12 columns]

# %%
df_exploded.to_csv("/content/drive/MyDrive/BOE/bank_of_england/data/model_outputs/Topic_Modelling_am/Final topic model/tqc_topic_model_ubs_breakdown1.csv", index=False)
print("CSV file saved successfully.")
# Out:
# CSV file saved successfully.
