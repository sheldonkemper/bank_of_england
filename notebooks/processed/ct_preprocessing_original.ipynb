# %% [markdown]
# <a href="https://colab.research.google.com/github/sheldonkemper/bank_of_england/blob/tidy_up_preprocessing_notebook/notebooks/processed/ct_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
===================================================
Author: Chiaki Tachikawa
Role: Data Science Lead, Bank of England Employer Project (Quant Collective)
LinkedIn: https://www.linkedin.com/in/chiaki-tachikawa
Date: 2025-02-13
Version: 1.1

Description:
    This notebook implements a system for cleaning and exporting transcript data for the Bank of England project. The workflow includes:
    - Importing necessary libraries and downloading NLTK data.
    - Defining and applying a `preprocessor` function to clean and tokenize text data.
    - Reading and preprocessing various CSV files containing transcript data.
    - Exporting the preprocessed data to new CSV files for further analysis.

===================================================
"""
# Out:
# '\n===================================================\nAuthor: Chiaki Tachikawa\nRole: Data Science Lead, Bank of England Employer Project (Quant Collective)\nLinkedIn: https://www.linkedin.com/in/chiaki-tachikawa\nDate: 2025-02-13\nVersion: 1.1\n\nDescription:\n    This notebook implements a system for cleaning and exporting transcript data for the Bank of England project. The workflow includes:\n    - Importing necessary libraries and downloading NLTK data.\n    - Defining and applying a `preprocessor` function to clean and tokenize text data.\n    - Reading and preprocessing various CSV files containing transcript data.\n    - Exporting the preprocessed data to new CSV files for further analysis.\n\n===================================================\n'

# %% [markdown]
# # **Library**

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download("stopwords")
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download('wordnet')
from nltk.tokenize import word_tokenize, sent_tokenize
from collections import Counter
import regex as re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from google.colab import drive
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # **Function**

# %% [markdown]
# preprocessor function : The function modifies the DataFrame data in place, adding two new columns (col1 and col2) with preprocessed text.
#
#
# Input:
#   - name of dataframe
#   - name of column which contains the text to clean
#   - name of column which is tokenized
#   - name of column which is cleaned

# %%
#create function to preprocess data
def preprocessor (data, col, col1,col2):
  #Copy col1umn
  data[col1]=data[col]
  data[col2]=data[col]


  #Adding column1
  #Lower the lettercase
  data[col1] = data[col1].str.lower()

  #Remove stop words
  stop_words = set(stopwords.words("english"))
  data[col1] = data[col1].apply(lambda x: " ".join([word for word in str(x).split() if word not in (stop_words)]))

  #Tokenize the word
  data[col1] = data[col1].apply(nltk.word_tokenize)

  #Remove numbers
  data[col1] = data[col1].apply(lambda x: [word for word in x if not word.isdigit()])

  #remove symbol from comments
  data[col1] = data[col1].apply(lambda x: [word for word in x if x!=""])

  #remove short word
  data[col1] = data[col1].apply(lambda x: [word for word in x if len(word)>2])

  #remove symbols
  data[col1] = data[col1].apply (lambda x: [re.sub(r"[^a-z]", "", word) for word in x])

  #lemmatization
  lemmatizer = WordNetLemmatizer()
  data[col1] = data[col1].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])



  #Adding column2
  #Lower the lettercase
  data[col2] = data[col2].str.lower()

  #Remove stop words
  stop_words = set(stopwords.words("english"))
  data[col2] = data[col2].apply(lambda x: " ".join([word for word in str(x).split() if word not in (stop_words)]))

  #remove symbols
  data[col2] = data[col2].apply (lambda x: [re.sub(r"[.,'?]", "", x)])

  return

# %% [markdown]
# find_row: This function searches upwards from the given current_row_num in the DataFrame df to find the first row where the value in column "M" is "A". It returns the index of that row. If no such row is found, it returns 0

# %%
def find_row (df, col, current_row_num):
  #list_name=[]
  i = current_row_num-1
  while i > 0:
    if df[col][i] == "A":
      break
    else:
      i-=1
  return i

# %% [markdown]
# find_row_empty: This function searches upwards from the given current_row_num to find the first row where col1 has the value "A" and col2 is not an empty list. It returns the index of that row.

# %%
def find_row_empty (df, col1, col2, current_row_num):
  #list_name=[]
  i = current_row_num-1
  while i > 0:
    if df[col1][i] == "A" and df[col2][i] != []:
      break
    else:
      i-=1
  return i

# %%
def create_ques_num_column (data, new_col,marker_col):
  #Create question number column
  data[new_col]=None
  #set global var to count question number
  num = 0
  #if Q was found, num adds 1 otherwise none
  for i in data.index:
    if data.loc[i,marker_col]=="Q":
      data.at[i,new_col]=num
      num +=1
    else:
      continue

# %%
# Function to extract names
def extract_name(full_string):
    return full_string.split(',')[0]

# %%
#check if there is "A" before "Q" from the current location
def find_last_a (df, col, current_row_num):
  #list_name=[]
  i = current_row_num-1
  while i > 0:
    if df[col][i] == "Q":
      j = i-1
      while j > 0:
        if df[col][j]=="A":
          pass
        else:
          break
        j-=1
      break
    else:
      i-=1
  return i

# %% [markdown]
# ## **Data**

# %%
#drive.mount('/content/drive')

# %%
#!ls"/content/bank_of_england/data/preprocessed_data/Archived/jpmorgan_qa_section_preprocessed.csv"

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# JP Morgan QA section

# %%
"""
#Obtaining management discussion / git bash
# !git clone https://github.com/sheldonkemper/bank_of_england.git
# !git switch Preprocessing
# %cd bank_of_england/data/preprocessed_data/archived
# %ls
"""
# Out:
# '\n#Obtaining management discussion / git bash\n!git clone https://github.com/sheldonkemper/bank_of_england.git\n!git switch Preprocessing\n%cd bank_of_england/data/preprocessed_data/archived\n%ls\n'

# %%
#Defining qa_data
qa_data = pd.read_csv("/content/drive/MyDrive/bank_of_england/data/preprocessed_data/original_jpmorgan_qa_section.csv")
qa_data.head()
# Out:
#                                              speaker  \
# 0  Jim Mitchell, Analyst, Seaport Global Securiti...
# 1  Jeremy Barnum, Chief Financial Officer, JPMorg...
# 2  Jim Mitchell, Analyst, Seaport Global Securiti...
# 3  Jeremy Barnum, Chief Financial Officer, JPMorg...
# 4  Jim Mitchell, Analyst, Seaport Global Securiti...
#
#                                        job_title marker  \
# 0         Analyst, Seaport Global Securities LLC      Q
# 1  Chief Financial Officer, JPMorgan Chase & Co.      A
# 2         Analyst, Seaport Global Securities LLC      Q
# 3  Chief Financial Officer, JPMorgan Chase & Co.      A
# 4         Analyst, Seaport Global Securities LLC      Q
#
#                                            utterance  \
# 0  Thanks. Good morning. Hey, Jeremy, you talked ...
# 1  Yeah, sure. Thanks, Jim. So, yeah, so when we ...
# 2  Okay. But I guess just one follow-up on that. ...
# 3  I wouldn't necessarily assume that the evoluti...
# 4  Okay. Great. Thanks. 5 Operator: Next, we'll g...
#
#                        filename financial_quarter   call_date
# 0  2q23-earnings-transcript.pdf              2Q23  2023-07-14
# 1  2q23-earnings-transcript.pdf              2Q23  2023-07-14
# 2  2q23-earnings-transcript.pdf              2Q23  2023-07-14
# 3  2q23-earnings-transcript.pdf              2Q23  2023-07-14
# 4  2q23-earnings-transcript.pdf              2Q23  2023-07-14

# %%
#ascend df by financial_quarter
quarter_order = ["1Q23", "2Q23","3Q23","4Q23","1Q24","2Q24","3Q24","4Q24"]
qa_data["financial_quarter"] = pd.Categorical(qa_data["financial_quarter"], categories=quarter_order, ordered=True)
qa_data = qa_data.sort_values("financial_quarter", kind="mergesort")

# %%
#preprocessing data
preprocessor(qa_data, "utterance", "question_tokenised_data", "question_cleaned")
preprocessor(qa_data,"utterance","answer_tokenised_data","answer_cleaned")

# %%
#remove operater
#qa_data = qa_data.loc[qa_data["speaker"]!="Operator"]

#remove less than 20 words
qa_data["count"] = qa_data["question_tokenised_data"].apply(lambda x: len(x))
qa_data = qa_data.loc[qa_data["count"]>20]
qa_data.head()
# Out:
#                                                speaker  \
# 216         Steven Chubak, Analyst, Wolfe Research LLC
# 217  Jamie Dimon, Chairman & Chief Executive Office...
# 221  Jamie Dimon, Chairman & Chief Executive Office...
# 224                  Ken Usdin, Analyst, Jefferies LLC
# 225  Jeremy Barnum, Chief Financial Officer, JPMorg...
#
#                                              job_title marker  \
# 216                        Analyst, Wolfe Research LLC      Q
# 217  Chairman & Chief Executive Officer, JPMorgan C...      A
# 221  Chairman & Chief Executive Officer, JPMorgan C...      A
# 224                             Analyst, Jefferies LLC      Q
# 225      Chief Financial Officer, JPMorgan Chase & Co.      A
#
#                                              utterance  \
# 216  So, Jamie, I was actually hoping to get your p...
# 217  Well, I think you were already kind of complet...
# 221  Well, we've told you that we're kind of pencil...
# 224  Hey, thanks. Good morning. Hey, Jeremy, I was ...
# 225  Yeah, sure. So let me just summarize the drive...
#
#                          filename financial_quarter   call_date  \
# 216  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 217  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 221  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 224  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 225  1q23-earnings-transcript.pdf              1Q23  2023-04-14
#
#                                question_tokenised_data  \
# 216  [jamie, actually, hoping, get, perspective, se...
# 217  [well, think, already, kind, complete, answeri...
# 221  [well, ve, told, re, kind, penciling, billion,...
# 224  [hey, thanks, good, morning, hey, jeremy, wond...
# 225  [yeah, sure, let, summarize, driver, change, o...
#
#                                       question_cleaned  \
# 216  [so jamie actually hoping get perspective see ...
# 217  [well think already kind complete answering qu...
# 221  [well weve told were kind penciling $12 billio...
# 224  [hey thanks good morning hey jeremy wondering ...
# 225  [yeah sure let summarize drivers change outloo...
#
#                                  answer_tokenised_data  \
# 216  [jamie, actually, hoping, get, perspective, se...
# 217  [well, think, already, kind, complete, answeri...
# 221  [well, ve, told, re, kind, penciling, billion,...
# 224  [hey, thanks, good, morning, hey, jeremy, wond...
# 225  [yeah, sure, let, summarize, driver, change, o...
#
#                                         answer_cleaned  count
# 216  [so jamie actually hoping get perspective see ...     54
# 217  [well think already kind complete answering qu...     84
# 221  [well weve told were kind penciling $12 billio...     30
# 224  [hey thanks good morning hey jeremy wondering ...     35
# 225  [yeah sure let summarize drivers change outloo...    111

# %%
#reset index
qa_data.reset_index(drop=True, inplace=True)
qa_data.head()
# Out:
#                                              speaker  \
# 0         Steven Chubak, Analyst, Wolfe Research LLC
# 1  Jamie Dimon, Chairman & Chief Executive Office...
# 2  Jamie Dimon, Chairman & Chief Executive Office...
# 3                  Ken Usdin, Analyst, Jefferies LLC
# 4  Jeremy Barnum, Chief Financial Officer, JPMorg...
#
#                                            job_title marker  \
# 0                        Analyst, Wolfe Research LLC      Q
# 1  Chairman & Chief Executive Officer, JPMorgan C...      A
# 2  Chairman & Chief Executive Officer, JPMorgan C...      A
# 3                             Analyst, Jefferies LLC      Q
# 4      Chief Financial Officer, JPMorgan Chase & Co.      A
#
#                                            utterance  \
# 0  So, Jamie, I was actually hoping to get your p...
# 1  Well, I think you were already kind of complet...
# 2  Well, we've told you that we're kind of pencil...
# 3  Hey, thanks. Good morning. Hey, Jeremy, I was ...
# 4  Yeah, sure. So let me just summarize the drive...
#
#                        filename financial_quarter   call_date  \
# 0  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 1  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 2  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 3  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 4  1q23-earnings-transcript.pdf              1Q23  2023-04-14
#
#                              question_tokenised_data  \
# 0  [jamie, actually, hoping, get, perspective, se...
# 1  [well, think, already, kind, complete, answeri...
# 2  [well, ve, told, re, kind, penciling, billion,...
# 3  [hey, thanks, good, morning, hey, jeremy, wond...
# 4  [yeah, sure, let, summarize, driver, change, o...
#
#                                     question_cleaned  \
# 0  [so jamie actually hoping get perspective see ...
# 1  [well think already kind complete answering qu...
# 2  [well weve told were kind penciling $12 billio...
# 3  [hey thanks good morning hey jeremy wondering ...
# 4  [yeah sure let summarize drivers change outloo...
#
#                                answer_tokenised_data  \
# 0  [jamie, actually, hoping, get, perspective, se...
# 1  [well, think, already, kind, complete, answeri...
# 2  [well, ve, told, re, kind, penciling, billion,...
# 3  [hey, thanks, good, morning, hey, jeremy, wond...
# 4  [yeah, sure, let, summarize, driver, change, o...
#
#                                       answer_cleaned  count
# 0  [so jamie actually hoping get perspective see ...     54
# 1  [well think already kind complete answering qu...     84
# 2  [well weve told were kind penciling $12 billio...     30
# 3  [hey thanks good morning hey jeremy wondering ...     35
# 4  [yeah sure let summarize drivers change outloo...    111

# %%
#Create question number column
create_ques_num_column(qa_data,"question_number_inline","marker")
# Out:
# <ipython-input-403-53017643a2e6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[new_col]=None

# %%
qa_data.head()
# Out:
#                                              speaker  \
# 0         Steven Chubak, Analyst, Wolfe Research LLC
# 1  Jamie Dimon, Chairman & Chief Executive Office...
# 2  Jamie Dimon, Chairman & Chief Executive Office...
# 3                  Ken Usdin, Analyst, Jefferies LLC
# 4  Jeremy Barnum, Chief Financial Officer, JPMorg...
#
#                                            job_title marker  \
# 0                        Analyst, Wolfe Research LLC      Q
# 1  Chairman & Chief Executive Officer, JPMorgan C...      A
# 2  Chairman & Chief Executive Officer, JPMorgan C...      A
# 3                             Analyst, Jefferies LLC      Q
# 4      Chief Financial Officer, JPMorgan Chase & Co.      A
#
#                                            utterance  \
# 0  So, Jamie, I was actually hoping to get your p...
# 1  Well, I think you were already kind of complet...
# 2  Well, we've told you that we're kind of pencil...
# 3  Hey, thanks. Good morning. Hey, Jeremy, I was ...
# 4  Yeah, sure. So let me just summarize the drive...
#
#                        filename financial_quarter   call_date  \
# 0  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 1  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 2  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 3  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 4  1q23-earnings-transcript.pdf              1Q23  2023-04-14
#
#                              question_tokenised_data  \
# 0  [jamie, actually, hoping, get, perspective, se...
# 1  [well, think, already, kind, complete, answeri...
# 2  [well, ve, told, re, kind, penciling, billion,...
# 3  [hey, thanks, good, morning, hey, jeremy, wond...
# 4  [yeah, sure, let, summarize, driver, change, o...
#
#                                     question_cleaned  \
# 0  [so jamie actually hoping get perspective see ...
# 1  [well think already kind complete answering qu...
# 2  [well weve told were kind penciling $12 billio...
# 3  [hey thanks good morning hey jeremy wondering ...
# 4  [yeah sure let summarize drivers change outloo...
#
#                                answer_tokenised_data  \
# 0  [jamie, actually, hoping, get, perspective, se...
# 1  [well, think, already, kind, complete, answeri...
# 2  [well, ve, told, re, kind, penciling, billion,...
# 3  [hey, thanks, good, morning, hey, jeremy, wond...
# 4  [yeah, sure, let, summarize, driver, change, o...
#
#                                       answer_cleaned  count  \
# 0  [so jamie actually hoping get perspective see ...     54
# 1  [well think already kind complete answering qu...     84
# 2  [well weve told were kind penciling $12 billio...     30
# 3  [hey thanks good morning hey jeremy wondering ...     35
# 4  [yeah sure let summarize drivers change outloo...    111
#
#   question_number_inline
# 0                      0
# 1                   None
# 2                   None
# 3                      1
# 4                   None

# %%
#adding new columns
qa_data["analyst"]=None
qa_data["analyst_title"]=None
qa_data["metadata_question"]=None
qa_data["question_num"]=None

#

for i in qa_data.index:
    name_list=[]
    title_list=[]
    question_list=[]
    quest_num_list=[]
    #If the value in the "marker" column at row i is "Q", then set the values of "analyst", "analyst_title", "metadata_question", and "question_num" columns at row i to "x".
    if qa_data.loc[i,"marker"]=="Q":
      qa_data.at[i,"analyst"]="x"
      qa_data.at[i,"analyst_title"]="x"
      qa_data.at[i,"metadata_question"]="x"
      qa_data.at[i,"question_num"]="x"
    elif find_last_a(qa_data,"marker",i) >=0 and qa_data.loc[i-1,"marker"]=="Q":
      name_list.append(qa_data["speaker"][i-1])
      title_list.append(qa_data["job_title"][i-1])
      question_list.append(qa_data["utterance"][i-1])
      quest_num_list.append(str(qa_data["question_number_inline"][i-1]))
    elif find_last_a(qa_data,"marker",i) >=0 and qa_data.loc[i-1,"marker"]=="A":
      qa_data.at[i,"analyst"] = qa_data.at[i-1,"analyst"]
      qa_data.at[i, "analyst_title"] = qa_data.at[i-1,"analyst_title"]
      qa_data.at[i,"metadata_question"]=qa_data.at[i-1, "metadata_question"]
      qa_data.at[i,"question_num"] = qa_data.at[i-1, "question_num"]

    #Initialize lists and populate them with "speaker", "job_title", "utterance", and "question_number_inline" values from rows between last_a and i in qa_data.
    else:
      last_a = find_row(qa_data,"marker", i)+ 1
      for j in range(last_a, i):
        name_list.append(qa_data["speaker"][j])
        title_list.append(qa_data["job_title"][j])
        question_list.append(qa_data["utterance"][j])
        quest_num_list.append(str(qa_data["question_number_inline"][j]))
 # Assign the lists name_list, title_list, question_list, and quest_num_list to the "analyst", "analyst_title", "metadata_question", and "question_num" columns at row i in qa_data, respectively.
    qa_data.at[i,"analyst"]=name_list
    qa_data.at[i,"analyst_title"]=title_list
    qa_data.at[i,"metadata_question"]=question_list
    qa_data.at[i,"question_num"]=quest_num_list

# %%
qa_data.head()
# Out:
#                                              speaker  \
# 0         Steven Chubak, Analyst, Wolfe Research LLC
# 1  Jamie Dimon, Chairman & Chief Executive Office...
# 2  Jamie Dimon, Chairman & Chief Executive Office...
# 3                  Ken Usdin, Analyst, Jefferies LLC
# 4  Jeremy Barnum, Chief Financial Officer, JPMorg...
#
#                                            job_title marker  \
# 0                        Analyst, Wolfe Research LLC      Q
# 1  Chairman & Chief Executive Officer, JPMorgan C...      A
# 2  Chairman & Chief Executive Officer, JPMorgan C...      A
# 3                             Analyst, Jefferies LLC      Q
# 4      Chief Financial Officer, JPMorgan Chase & Co.      A
#
#                                            utterance  \
# 0  So, Jamie, I was actually hoping to get your p...
# 1  Well, I think you were already kind of complet...
# 2  Well, we've told you that we're kind of pencil...
# 3  Hey, thanks. Good morning. Hey, Jeremy, I was ...
# 4  Yeah, sure. So let me just summarize the drive...
#
#                        filename financial_quarter   call_date  \
# 0  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 1  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 2  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 3  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 4  1q23-earnings-transcript.pdf              1Q23  2023-04-14
#
#                              question_tokenised_data  \
# 0  [jamie, actually, hoping, get, perspective, se...
# 1  [well, think, already, kind, complete, answeri...
# 2  [well, ve, told, re, kind, penciling, billion,...
# 3  [hey, thanks, good, morning, hey, jeremy, wond...
# 4  [yeah, sure, let, summarize, driver, change, o...
#
#                                     question_cleaned  \
# 0  [so jamie actually hoping get perspective see ...
# 1  [well think already kind complete answering qu...
# 2  [well weve told were kind penciling $12 billio...
# 3  [hey thanks good morning hey jeremy wondering ...
# 4  [yeah sure let summarize drivers change outloo...
#
#                                answer_tokenised_data  \
# 0  [jamie, actually, hoping, get, perspective, se...
# 1  [well, think, already, kind, complete, answeri...
# 2  [well, ve, told, re, kind, penciling, billion,...
# 3  [hey, thanks, good, morning, hey, jeremy, wond...
# 4  [yeah, sure, let, summarize, driver, change, o...
#
#                                       answer_cleaned  count  \
# 0  [so jamie actually hoping get perspective see ...     54
# 1  [well think already kind complete answering qu...     84
# 2  [well weve told were kind penciling $12 billio...     30
# 3  [hey thanks good morning hey jeremy wondering ...     35
# 4  [yeah sure let summarize drivers change outloo...    111
#
#   question_number_inline                                       analyst  \
# 0                      0                                            []
# 1                   None  [Steven Chubak, Analyst, Wolfe Research LLC]
# 2                   None                                            []
# 3                      1                                            []
# 4                   None           [Ken Usdin, Analyst, Jefferies LLC]
#
#                    analyst_title  \
# 0                             []
# 1  [Analyst, Wolfe Research LLC]
# 2                             []
# 3                             []
# 4       [Analyst, Jefferies LLC]
#
#                                    metadata_question question_num
# 0                                                 []           []
# 1  [So, Jamie, I was actually hoping to get your ...          [0]
# 2                                                 []           []
# 3                                                 []           []
# 4  [Hey, thanks. Good morning. Hey, Jeremy, I was...          [1]

# %%
for i in range(len(qa_data)):
  #if the first row is answer, then return all analyst columns as x, if the row is answer and there is not analyst, then popurate questioner analyst name and other data, otherwise pass the function
  if i ==0 and qa_data["marker"][i]=="A":
    qa_data.at[i,"analyst"] ="x"
    qa_data.at[i,"analyst_title"] ="x"
    qa_data.at[i,"metadata_question"] ="x"
    qa_data.at[i,"question_num"]="x"
  elif qa_data["marker"][i]=="A"and qa_data["analyst"][i]==[]:
    a = find_row_empty(qa_data,"marker","analyst",i)
    qa_data.at[i,"analyst"] = qa_data.loc[a,"analyst"]
    qa_data.at[i,"analyst_title"] = qa_data.loc[a,"analyst_title"]
    qa_data.at[i,"metadata_question"] = qa_data.loc[a,"metadata_question"]
    qa_data.at[i,"question_num"] =qa_data.loc[a,"question_num"]
  else:
    continue

# %%
#rename column
qa_data.rename(columns={"utterance":"metadata"},inplace=True)

# %%
#reorganise column
qa_data=qa_data[["filename","financial_quarter","call_date","speaker","marker","question_num","job_title","metadata", "answer_cleaned","analyst","analyst_title","metadata_question","question_cleaned"]]

# %%
# Apply the function to the DataFrame
qa_data['speaker'] = qa_data['speaker'].apply(extract_name)
# Out:
# <ipython-input-422-3b2ec04a312b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qa_data['speaker'] = qa_data['speaker'].apply(extract_name)

# %%
"""
#ascend df by financial_quarter
quarter_order = ["1Q23", "2Q23","3Q23","4Q23","1Q24","2Q24","3Q24","4Q24"]
qa_data["financial_quarter"] = pd.Categorical(qa_data["financial_quarter"], categories=quarter_order, ordered=True)
df_sorted = qa_data.sort_values("financial_quarter", kind="mergesort")
"""
# Out:
# '\n#ascend df by financial_quarter\nquarter_order = ["1Q23", "2Q23","3Q23","4Q23","1Q24","2Q24","3Q24","4Q24"]\nqa_data["financial_quarter"] = pd.Categorical(qa_data["financial_quarter"], categories=quarter_order, ordered=True)\ndf_sorted = qa_data.sort_values("financial_quarter", kind="mergesort")\n'

# %%
qa_data.head(20)
# Out:
#                         filename financial_quarter   call_date  \
# 0   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 1   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 2   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 3   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 4   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 5   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 6   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 7   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 8   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 9   1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 10  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 11  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 12  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 13  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 14  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 15  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 16  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 17  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 18  1q23-earnings-transcript.pdf              1Q23  2023-04-14
# 19  1q23-earnings-transcript.pdf              1Q23  2023-04-14
#
#            speaker marker question_num  \
# 0    Steven Chubak      Q           []
# 1      Jamie Dimon      A          [0]
# 2      Jamie Dimon      A          [0]
# 3        Ken Usdin      Q           []
# 4    Jeremy Barnum      A          [1]
# 5        Ken Usdin      Q           []
# 6      Jamie Dimon      A          [2]
# 7    John McDonald      Q           []
# 8    Jeremy Barnum      A          [3]
# 9    John McDonald      Q           []
# 10     Jamie Dimon      A          [4]
# 11   Jeremy Barnum      A          [4]
# 12  Erika Najarian      Q           []
# 13   Jeremy Barnum      A          [5]
# 14    Jim Mitchell      Q           []
# 15   Jeremy Barnum      A          [6]
# 16     Jamie Dimon      A          [6]
# 17    Jim Mitchell      Q           []
# 18   Jeremy Barnum      A          [7]
# 19  Gerard Cassidy      Q           []
#
#                                             job_title  \
# 0                         Analyst, Wolfe Research LLC
# 1   Chairman & Chief Executive Officer, JPMorgan C...
# 2   Chairman & Chief Executive Officer, JPMorgan C...
# 3                              Analyst, Jefferies LLC
# 4       Chief Financial Officer, JPMorgan Chase & Co.
# 5                              Analyst, Jefferies LLC
# 6   Chairman & Chief Executive Officer, JPMorgan C...
# 7                        Analyst, Autonomous Research
# 8       Chief Financial Officer, JPMorgan Chase & Co.
# 9                        Analyst, Autonomous Research
# 10  Chairman & Chief Executive Officer, JPMorgan C...
# 11      Chief Financial Officer, JPMorgan Chase & Co.
# 12                        Analyst, UBS Securities LLC
# 13      Chief Financial Officer, JPMorgan Chase & Co.
# 14             Analyst, Seaport Global Securities LLC
# 15      Chief Financial Officer, JPMorgan Chase & Co.
# 16  Chairman & Chief Executive Officer, JPMorgan C...
# 17             Analyst, Seaport Global Securities LLC
# 18      Chief Financial Officer, JPMorgan Chase & Co.
# 19                   Analyst, RBC Capital Markets LLC
#
#                                              metadata  \
# 0   So, Jamie, I was actually hoping to get your p...
# 1   Well, I think you were already kind of complet...
# 2   Well, we've told you that we're kind of pencil...
# 3   Hey, thanks. Good morning. Hey, Jeremy, I was ...
# 4   Yeah, sure. So let me just summarize the drive...
# 5   Yeah, and as a follow-up on the point about ra...
# 6   Well first of all, I don't quite believe it. S...
# 7   Hi, thanks. Jeremy, wanted to follow up again ...
# 8   Yeah. John, it's a really good question, and w...
# 9   Okay. And then I wanted to ask Jamie – there's...
# 10  Yeah. I wouldn't use the word credit crunch if...
# 11  Yeah. So, Erika, as you know, we take – not go...
# 12  So, as you think about all of what you've just...
# 13  Okay. Let's take a crack. Let's see what the b...
# 14  Hey. Good morning. Maybe just a little bit on ...
# 15  Yeah. A couple things there. So, first of all,...
# 16  If I add, I would say, categorically, there's ...
# 17  No, fair – all fair points. And maybe just a f...
# 18  Yeah. And we always say, right, we underwrite ...
# 19  In your comments about your CET1 ratio, obviou...
#
#                                        answer_cleaned  \
# 0   [so jamie actually hoping get perspective see ...
# 1   [well think already kind complete answering qu...
# 2   [well weve told were kind penciling $12 billio...
# 3   [hey thanks good morning hey jeremy wondering ...
# 4   [yeah sure let summarize drivers change outloo...
# 5   [yeah follow-up point rate expectations coming...
# 6   [well first all quite believe it fed rate curv...
# 7   [hi thanks jeremy wanted follow drivers nii re...
# 8   [yeah john really good question weve obviously...
# 9   [okay wanted ask jamie – theres narrative indu...
# 10  [yeah use word credit crunch you obviously the...
# 11  [yeah so erika know take – going go lot detail...
# 12  [so think told us – $81 billion nii year knows...
# 13  [okay lets take crack lets see boss thinks thi...
# 14  [hey good morning maybe little bit deposit tho...
# 15  [yeah couple things there so first all know ri...
# 16  [add would say categorically theres pricing po...
# 17  [no fair – fair points maybe follow-up johns q...
# 18  [yeah always say right underwrite cycle think ...
# 19  [comments cet1 ratio obviously came strong 138...
#
#                                               analyst  \
# 0                                                  []
# 1        [Steven Chubak, Analyst, Wolfe Research LLC]
# 2        [Steven Chubak, Analyst, Wolfe Research LLC]
# 3                                                  []
# 4                 [Ken Usdin, Analyst, Jefferies LLC]
# 5                                                  []
# 6                 [Ken Usdin, Analyst, Jefferies LLC]
# 7                                                  []
# 8       [John McDonald, Analyst, Autonomous Research]
# 9                                                  []
# 10      [John McDonald, Analyst, Autonomous Research]
# 11      [John McDonald, Analyst, Autonomous Research]
# 12                                                 []
# 13      [Erika Najarian, Analyst, UBS Securities LLC]
# 14                                                 []
# 15  [Jim Mitchell, Analyst, Seaport Global Securit...
# 16  [Jim Mitchell, Analyst, Seaport Global Securit...
# 17                                                 []
# 18  [Jim Mitchell, Analyst, Seaport Global Securit...
# 19                                                 []
#
#                                analyst_title  \
# 0                                         []
# 1              [Analyst, Wolfe Research LLC]
# 2              [Analyst, Wolfe Research LLC]
# 3                                         []
# 4                   [Analyst, Jefferies LLC]
# 5                                         []
# 6                   [Analyst, Jefferies LLC]
# 7                                         []
# 8             [Analyst, Autonomous Research]
# 9                                         []
# 10            [Analyst, Autonomous Research]
# 11            [Analyst, Autonomous Research]
# 12                                        []
# 13             [Analyst, UBS Securities LLC]
# 14                                        []
# 15  [Analyst, Seaport Global Securities LLC]
# 16  [Analyst, Seaport Global Securities LLC]
# 17                                        []
# 18  [Analyst, Seaport Global Securities LLC]
# 19                                        []
#
#                                     metadata_question  \
# 0                                                  []
# 1   [So, Jamie, I was actually hoping to get your ...
# 2   [So, Jamie, I was actually hoping to get your ...
# 3                                                  []
# 4   [Hey, thanks. Good morning. Hey, Jeremy, I was...
# 5                                                  []
# 6   [Yeah, and as a follow-up on the point about r...
# 7                                                  []
# 8   [Hi, thanks. Jeremy, wanted to follow up again...
# 9                                                  []
# 10  [Okay. And then I wanted to ask Jamie – there'...
# 11  [Okay. And then I wanted to ask Jamie – there'...
# 12                                                 []
# 13  [So, as you think about all of what you've jus...
# 14                                                 []
# 15  [Hey. Good morning. Maybe just a little bit on...
# 16  [Hey. Good morning. Maybe just a little bit on...
# 17                                                 []
# 18  [No, fair – all fair points. And maybe just a ...
# 19                                                 []
#
#                                      question_cleaned
# 0   [so jamie actually hoping get perspective see ...
# 1   [well think already kind complete answering qu...
# 2   [well weve told were kind penciling $12 billio...
# 3   [hey thanks good morning hey jeremy wondering ...
# 4   [yeah sure let summarize drivers change outloo...
# 5   [yeah follow-up point rate expectations coming...
# 6   [well first all quite believe it fed rate curv...
# 7   [hi thanks jeremy wanted follow drivers nii re...
# 8   [yeah john really good question weve obviously...
# 9   [okay wanted ask jamie – theres narrative indu...
# 10  [yeah use word credit crunch you obviously the...
# 11  [yeah so erika know take – going go lot detail...
# 12  [so think told us – $81 billion nii year knows...
# 13  [okay lets take crack lets see boss thinks thi...
# 14  [hey good morning maybe little bit deposit tho...
# 15  [yeah couple things there so first all know ri...
# 16  [add would say categorically theres pricing po...
# 17  [no fair – fair points maybe follow-up johns q...
# 18  [yeah always say right underwrite cycle think ...
# 19  [comments cet1 ratio obviously came strong 138...

# %% [markdown]
# JP morgan management discussion

# %%
# %ls

# %%
#defining santader dataframe
jpmorgan_body_df=pd.read_csv("jpmorgan_management_discussion.csv")
jpmorgan_body_df.head()

# %%
#preprocess data
preprocessor(jpmorgan_body_df, "chunk_text", "tokenized_data","cleaned_data")

# %%
jpmorgan_body_df.head()

# %% [markdown]
# UBS qna section

# %%
# %ls

# %%
#define ubs q&a data
ubs_qna_df=pd.read_csv("ubs_qna_section.csv")

# %%
#preprocessing ubs Q&A data
preprocessor(ubs_qna_df, "utterance", "tokenized_data","cleaned_data")

# %%
ubs_qna_df.head()

# %% [markdown]
# UBS management discussion

# %%
# %ls

# %%
#defining ubs management discussion
ubs_manag_df=pd.read_csv("ubs_management_discussion.csv")
ubs_manag_df.head()

# %%
#preprocessing ubs management discussion
preprocessor(ubs_manag_df,"utterance", "tokenized_data","cleaned_data")
ubs_manag_df.head()

# %% [markdown]
# # **Export the output as a csv file**

# %% [markdown]
# JP morgan QA section

# %%
#export preprocessed data
preprocessed_qa_csv_path1 = "/content/drive/MyDrive/bank_of_england/data/preprocessed_data/jpmorgan_qna_df_preprocessed_ver7.csv"
qa_data.to_csv(preprocessed_qa_csv_path1, index=False)

# %% [markdown]
# JP morgan management discussion

# %%
#export preprocessed data
preprocessed_qa_csv_path2 = "/content/sample_data/jpmorgan_management_df_preprocessed.csv"
jpmorgan_body_df.to_csv(preprocessed_qa_csv_path2, index=False)

# %% [markdown]
# UBS QA section

# %%
#export preprocessed data
preprocessed_qa_csv_path3 = "/content/sample_data/ubs_qa_df_preprocessed.csv"
ubs_qna_df.to_csv(preprocessed_qa_csv_path3, index=False)

# %% [markdown]
# UBS management discussion

# %%
#export preprocessed data
preprocessed_qa_csv_path4 = "/content/sample_data/ubs_management_df_preprocessed.csv"
ubs_manag_df.to_csv(preprocessed_qa_csv_path4, index=False)
